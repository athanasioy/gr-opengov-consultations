# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from DataObjects.article import Article
from DataObjects.legislation import Legislation
from DataObjects.public_consultation import PublicConsultation
from DataObjects.base import Base
from typing import Any
import functools
import requests
import re
from sqlalchemy import create_engine, select, union_all, func, delete, and_
from sqlalchemy.orm import Session
from typing import Callable
from bs4 import BeautifulSoup
import os
from configparser import ConfigParser
from datetime import datetime
config = ConfigParser()
config.read("config.ini")
# Out:
# ['config.ini']

# %%
engine = create_engine(config.get('DEFAULT', 'db_file'))

# %%
def compose(*functions:Callable[...,Any]) -> Callable[...,Any]:
    """ Helper Function to chain the output of a function to another function as Input
    """

    return functools.reduce(lambda f,g: lambda x: g(f(x)), functions )

def extract_text_inside_quoations(text:str) -> str:
    pattern = r'«(.*?)»'
    matches = re.search(pattern=pattern,string=text)
    if matches:
        return matches.group(1).strip()
    else:
        return text.strip()

def extract_text_after_colon(text:str) ->str:
    pattern = ".+:\s?(.+)"
    matches = re.search(pattern=pattern, string=text)
    if matches:
        return matches.group(1).strip()
    else:
        return text.strip()

def remove_part_of_string(text:str, part_of_string:str) -> str:
    pattern = part_of_string+r"\s\S+(.+)"
    matches = re.match(pattern=pattern, string=text)
    if matches:
        return matches.group(1).strip()
    else:
        return text.strip()

def get_first_n_words(text:str, n:int = 4) -> str:
    return " ".join(text.split(" ")[:n])

# %%
phrases_to_skip =[
    "ολοκλήρωση της διαδικασίας",
    "ολοκλήρωση της δημόσιας διαβούλευσης επί",
    "δημόσια διαβούλευση για",
    "δημόσια διαβούλευση επί",
    "ρυθμίσεις για",
    "ρυθμισεις για"
    "ενσωμάτωση της οδηγίας",
    "επείγουσες ρυθμίσεις",
    "ολοκλήρωση δημοσίευσης ηλεκτρονικής δημόσιας διαβούλευσης",
    "ολοκλήρωση δημοσίευσης ηλεκτρονικής δημόσιας",
    "ολοκλήρωση διαβούλευσης",
    "δημόσια ηλεκτρονική διαβούλευση",
    "ανοιχτή δημόσια διαβούλευση",
    "κύρωση της σύμβασης",
    "τεχνικές προδιαγραφές για"

] # create a function for string using partial and compose
pre_process_title_fn = str.lower
pre_process_title_fn = compose(pre_process_title_fn,extract_text_inside_quoations)
pre_process_title_fn = compose(pre_process_title_fn,extract_text_inside_quoations)
pre_process_title_fn = compose(pre_process_title_fn,extract_text_after_colon)
for phrase in phrases_to_skip:
    pre_process_title_fn= compose(pre_process_title_fn,functools.partial(remove_part_of_string,part_of_string=phrase))

pre_process_title_fn = compose(pre_process_title_fn,get_first_n_words)

# %% [markdown]
# Test Functions

# %%
text = "Δημόσια Διαβούλευση για το Σχέδιο Νόμου «Χορήγηση ενισχύσεων σε ιδιωτικές επενδύσεις για την προώθηση της οικονομικής και κοινωνικής ανάπτυξης και την περιφερειακή σύγκλιση και άλλες διατάξεις»"
text = extract_text_inside_quoations(text) 
print(text)
text = get_first_n_words(text)
print(text)


text = "‘Δημόσια Διαβούλευση για τις δράσεις «Digi-content» και «Digi-retail»"
text = extract_text_after_colon(text) 
print(text)
text = remove_public_consultation_string(text)
print(text)
text = get_first_n_words(text)
print(text)
# Out:
# Χορήγηση ενισχύσεων σε ιδιωτικές επενδύσεις για την προώθηση της οικονομικής και κοινωνικής ανάπτυξης και την περιφερειακή σύγκλιση και άλλες διατάξεις
# Χορήγηση ενισχύσεων σε ιδιωτικές
# ‘Δημόσια Διαβούλευση για τις δράσεις «Digi-content» και «Digi-retail»
# ‘Δημόσια Διαβούλευση για τις δράσεις «Digi-content» και «Digi-retail»
# ‘Δημόσια Διαβούλευση για τις

# %%
# pre_process_title_fn = compose(str.lower,
#                                extract_text_inside_quoations,
#                                extract_text_after_colon,
#                                remove_public_consultation_string,
#                                remove_public_consultation_completed_string,
#                                remove_regularization_for_string,
#                                remove_incorporation_of_european_guidance_string,
#                                remove_urgent_regularization_for_string,
#                                get_first_n_words)

text = "Δημόσια Διαβούλευση για το Σχέδιο Νόμου «Χορήγηση ενισχύσεων σε ιδιωτικές επενδύσεις για την προώθηση της οικονομικής και κοινωνικής ανάπτυξης και την περιφερειακή σύγκλιση και άλλες διατάξεις»"
text = pre_process_title_fn(text)
print(text)
text2 = "Σχέδιο Νόμου: Ενίσχυση Κοινωνικής Αλληλεγγύης και  Εισφορά Κοινωνικής Ευθύνης"
text2 = pre_process_title_fn(text2)
print(text2)
txt3 = "Ολοκλήρωση της δημόσιας διαβούλευσης επί του Εθνικού Σχεδίου Δράσης για την Ψυχική Υγεία 2021-2030"
txt3 = pre_process_title_fn(txt3)
print(txt3)

txt4 = "Διαβούλευση επί του σχεδίου νόμου «Οργανισμοί Διαχείρισης και Προώθησης Προορισμού, Ιαματικές Πηγές Ελλάδας, Ναυάγιο Ζακύνθου, διατάξεις για τα τουριστικά γραφεία, τις τουριστικές επιχειρήσεις και τα τουριστικά καταλύματα και άλλες ρυθμίσεις για την τουριστική ανάπτυξη»"
txt4 = pre_process_title_fn(txt4)
print(txt4)
# Out:
# χορήγηση ενισχύσεων σε ιδιωτικές
# ενίσχυση κοινωνικής αλληλεγγύης και
# εθνικού σχεδίου δράσης για
# οργανισμοί διαχείρισης και προώθησης

# %%
with Session(engine) as sess:
    stmt = select(Legislation.title)
    titles = sess.execute(stmt).scalars()
    for title in titles:
        print(f"Title:{pre_process_title_fn(title)} <- {(title)}")
# Out:
# Title:αρση περιορισμων για την <- Ολοκλήρωση της δημόσιας ηλεκτρονικής διαβούλευσης για το σχέδιο νόμου του Υπουργείου Εσωτερικών με τίτλο «ΑΡΣΗ ΠΕΡΙΟΡΙΣΜΩΝ ΓΙΑ ΤΗΝ ΕΓΓΡΑΦΗ ΣΤΟΥΣ ΕΙΔΙΚΟΥΣ ΕΚΛΟΓΙΚΟΥΣ ΚΑΤΑΛΟΓΟΥΣ ΕΚΛΟΓΕΩΝ ΕΞΩΤΕΡΙΚΟΥ».
# Title:οδηγού προσβασιμότητας για ιστοτόπους <- Ανοιχτή δημόσια διαβούλευση του Οδηγού Προσβασιμότητας για ιστοτόπους και εφαρμογές για φορητές συσκευές των οργανισμών της Ελληνικής Δημόσιας Διοίκησης
ΕΚ του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου της 12ης Δεκεμβρίου 2006 σχετικά με το δικαίωμα εκμίσθωσης, το δικαίωμα δανεισμού και ορισμένα δικαιώματα συγγενικά προς την πνευματική ιδιοκτησία στον τομέα των προϊόντων της διάνοιας (κωδικοποίηση) – Ρυθμίσεις για την αναπαραγωγή πρόσθετου αντιτύπου από μη κερδοσκοπικές βιβλιοθήκες ή αρχεία, την εφαρμογή των Οδηγιών (ΕΕ) 789/2019, (ΕΕ) 790/2019 και 2016/115/ΕΚ και τη διευκρίνιση του πεδίου εφαρμογής της υποχρέωσης καταβολής εύλογης αμοιβής – Τροποποίηση ν. 2121/1993 και ν. 4481/2017»»
# Title:εξορθολογισμός ασφαλιστικής και συνταξιοδοτικής <- Ολοκλήρωση δημόσιας ηλεκτρονικής διαβούλευσης για το σχέδιο νόμου «Εξορθολογισμός ασφαλιστικής και συνταξιοδοτικής νομοθεσίας, ενίσχυση ευάλωτων κοινωνικών ομάδων και άλλες διατάξεις»
# Title:θεοφάνης ερμής θεοχαρόπουλος <- Εθνικός Μηχανισμός Εναέριας Έρευνας και Διάσωσης: Θεοφάνης Ερμής Θεοχαρόπουλος
# Title:αναμόρφωση και εκσυγχρονισμός του <- Αναμόρφωση και εκσυγχρονισμός του Σωφρονιστικού Κώδικα- Tροποποιήσεις στον ν. 2776/1999
# Title:σύσταση και οργάνωση νομικού <- Ολοκλήρωση της δημόσιας διαβούλευσης επί του σχεδίου νόμου «Σύσταση και οργάνωση νομικού προσώπου δημοσίου δικαίου με την επωνυμία «ΕΝΩΣΗ ΤΕΧΝΟΛΟΓΩΝ ΑΚΤΙΝΟΛΟΓΙΑΣ – ΑΚΤΙΝΟΘΕΡΑΠΕΙΑΣ ΕΛΛΑΔΑΣ» (Ε.Τ.Α.Α.Ε.), ρυθμίσεις για την αντιμετώπιση της πανδημίας του κορωνοϊού COVID-19 και την προστασία της δημόσιας υγείας και λοιπές διατάξεις»
# Title:ενίσχυση δημοσιότητας και διαφάνειας <- Ενίσχυση δημοσιότητας και διαφάνειας στον έντυπο και ηλεκτρονικό τύπο – Σύσταση Ηλεκτρονικών Μητρώων Έντυπου και Ηλεκτρονικού Τύπου και λοιπές ρυθμίσεις αρμοδιότητας της Γενικής Γραμματείας Επικοινωνίας και Ενημέρωσης
# Title:δημόσιες υπεραστικές και αστικές <- Ολοκλήρωση δημόσιας διαβούλευσης επί της νομοθετικής πρωτοβουλίας του Υπουργείου Υποδομών και Μεταφορών υπό τον τίτλο: «Δημόσιες υπεραστικές και αστικές τακτικές οδικές μεταφορές επιβατών»
# Title:εθνικη στρατηγικη για τις <- Δημόσια ηλεκτρονική διαβούλευση για την «ΕΘΝΙΚΗ ΣΤΡΑΤΗΓΙΚΗ ΓΙΑ ΤΙΣ ΕΝΕΡΓΗΤΙΚΕΣ ΠΟΛΙΤΙΚΕΣ ΑΠΑΣΧΟΛΗΣΗΣ»
# Title:αναβάθμιση της αστυνομικής εκπαίδευσης, <- Δημόσια ηλεκτρονική διαβούλευση επί της νομοθετικής πρωτοβουλίας του Υπουργείου Προστασίας του Πολίτη υπό τον τίτλο «Αναβάθμιση της αστυνομικής εκπαίδευσης, αναμόρφωση του πλαισίου οργάνωσης και λειτουργίας της Σχολής Αξιωματικών της Ελληνικής Αστυνομίας»
# Title:αναδυόμενες τεχνολογίες πληροφορικής και <- Αναδυόμενες τεχνολογίες πληροφορικής και επικοινωνιών, ενίσχυση της ψηφιακής διακυβέρνησης και άλλες διατάξεις
# Title:μεταρρυθμίσεις στην ιατρικώς υποβοηθούμενη <- Ολοκλήρωση της δημόσιας διαβούλευσης επί του σχεδίου νόμου «Μεταρρυθμίσεις στην ιατρικώς υποβοηθούμενη αναπαραγωγή»
# Title:εθνικό σύστημα επιτροπείας ασυνόδευτων <- Διαβούλευση επί της νομοθετικής πρωτοβουλίας του Υπουργείου Μετανάστευσης και Ασύλου, υπό τον τίτλο: «Εθνικό Σύστημα επιτροπείας ασυνόδευτων ανήλικων και πλαίσιο φιλοξενίας ασυνόδευτων ανήλικων»
# Title:εφαρμογή των διατάξεων της <- Δημόσια ηλεκτρονική διαβούλευση επί του σχεδίου Κοινής Απόφασης των Υπουργών Εργασίας και Κοινωνικών Υποθέσεων και Υγείας με τίτλο «Εφαρμογή των διατάξεων της περ. β), παρ.3, του άρθρου 5 του ν. 3846/2010 (Α΄66), όπως αντικαταστάθηκε με το άρθρο 67 του ν.4808/2021 (Α’ 101) περί παροχής εξ αποστάσεως εργασίας με τηλεργασία μετά από αίτηση του εργαζομένου»
# Title:αντιμετώπιση της πανδημίας του <- Δημόσια ηλεκτρονική διαβούλευση επί του σχεδίου νόμου «Ρυθμίσεις για την αντιμετώπιση της πανδημίας του κορωνοϊού COVID-19 και την προστασία της δημόσιας υγείας»
# Title:συμπληρωματικά μέτρα για την <- Δημόσια ηλεκτρονική διαβούλευση επί του σχεδίου νόμου του Υπουργείου Εσωτερικών υπό τον τίτλο «Συμπληρωματικά μέτρα για την εφαρμογή του Κανονισμού (ΕΕ) 2019/788 του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου σχετικά με την Ευρωπαϊκή Πρωτοβουλία Πολιτών και του Εκτελεστικού Κανονισμού (ΕΕ) 2019/1799 της Επιτροπής για τη θέσπιση τεχνικών προδιαγραφών για τα επιμέρους επιγραμμικά συστήματα συγκέντρωσης – Διατάξεις σχετικές με την εκλογική διαδικασία και τον έλεγχο εσόδων και δαπανών κομμάτων, συνασπισμών και υποψηφίων βουλευτών και αιρετών – Λοιπές διατάξεις Υπουργείου Εσωτερικών»
# Title:ενίσχυση της ποιότητας, της <- Δημόσια διαβούλευση επί του σχεδίου νόμου με τίτλο «Νέοι Ορίζοντες στα Ανώτατα Εκπαιδευτικά Ιδρύματα: Ενίσχυση της ποιότητας, της λειτουργικότητας και της σύνδεσης των ΑΕΙ με την κοινωνία και άλλες διατάξεις»
# Title:διαβούλευση για το σχέδιο <- Διαβούλευση για το σχέδιο της Έκθεσης Εθελοντικής Αξιολόγησης της Ελλάδας (Voluntary National Report) σχετικά με τους Στόχους Βιώσιμης Ανάπτυξης (ΣΒΑ)
# Title:ψηφιοποιηση των διαδικασιων επιδοσεων <- ΨΗΦΙΟΠΟΙΗΣΗ ΤΩΝ ΔΙΑΔΙΚΑΣΙΩΝ ΕΠΙΔΟΣΕΩΝ ΕΓΓΡΑΦΩΝ ΚΑΙ ΑΠΟΔΕΣΜΕΥΣΗ ΤΗΣ ΕΛΛΗΝΙΚΗΣ ΑΣΤΥΝΟΜΙΑΣ ΑΠΟ ΤΗ ΔΙΕΝΕΡΓΕΙΑ ΕΠΙΔΟΣΕΩΝ ΕΓΓΡΑΦΩΝ ΤΗΣ ΠΟΙΝΙΚΗΣ ΚΑΙ ΠΟΛΙΤΙΚΗΣ ΔΙΚΗΣ ΚΑΙ ΛΟΙΠΕΣ ΕΠΕΙΓΟΥΣΕΣ ΔΙΑΤΑΞΕΙΣ
# Title:το εθνικό σχέδιο δράσης <- Δημόσια ηλεκτρονική διαβούλευση για το Εθνικό Σχέδιο Δράσης για την Ισότητα των Φύλων 2021-2025
# Title:ενίσχυση διαφάνειας και λογοδοσίας <- Ενίσχυση διαφάνειας και λογοδοσίας σε θεσμικούς φορείς της Πολιτείας, αποκατάσταση ακεραιότητας Ενιαίου Συστήματος Κινητικότητας και λοιπές διατάξεις του Υπουργείου Εσωτερικών
# Title:εκσυγχρονισμός του ελληνικού κτηματολογίου, <- Δημόσια ηλεκτρονική διαβούλευση το σχέδιο νόμου με τίτλο: «Εκσυγχρονισμός του Ελληνικού Κτηματολογίου, νέες ψηφιακές υπηρεσίες και ενίσχυση της ψηφιακής διακυβέρνησης»
# Title:αναβάθμιση του σχολείου, ενδυνάμωση <- Δημόσια διαβούλευση επί του σχεδίου νόμου με τίτλο «Αναβάθμιση του σχολείου, ενδυνάμωση των εκπαιδευτικών και άλλες διατάξεις»
# Title:εισαγωγή κεφαλαιοποιητικού συστήματος προκαθορισμένων <- Δημόσια ηλεκτρονική διαβούλευση για το σχέδιο νόμου του Υπουργείου Εργασίας και Κοινωνικών Υποθέσεων με τίτλο: «Ασφαλιστική Μεταρρύθμιση για τη Νέα Γενιά: εισαγωγή κεφαλαιοποιητικού συστήματος προκαθορισμένων εισφορών στην επικουρική ασφάλιση, ίδρυση, οργάνωση και λειτουργία Ταμείου Επικουρικής Κεφαλαιοποιητικής Ασφάλισης και συναφείς διατάξεις»
# Title:αναμόρφωση διαδικασιών απελάσεων και <- Ολοκλήρωση της διαδικασίας της δημόσιας ηλεκτρονικής διαβούλευσης επί του σχεδίου νόμου  «Αναμόρφωση διαδικασιών απελάσεων και επιστροφών πολιτών τρίτων χωρών, ζητήματα αδειών διαμονής και διαδικασιών χορήγησης διεθνούς προστασίας και άλλες διατάξεις αρμοδιότητας Υπουργείου Μετανάστευσης και Ασύλου και Υπουργείου Προστασίας του Πολίτη»
# Title:οργανισμοί διαχείρισης και προώθησης <- Διαβούλευση επί του σχεδίου νόμου «Οργανισμοί Διαχείρισης και Προώθησης Προορισμού, Ιαματικές Πηγές Ελλάδας, Ναυάγιο Ζακύνθου, διατάξεις για τα τουριστικά γραφεία, τις τουριστικές επιχειρήσεις και τα τουριστικά καταλύματα και άλλες ρυθμίσεις για την τουριστική ανάπτυξη»
# Title:εθνική στρατηγική για την <- Δημόσια ηλεκτρονική διαβούλευση για την «Εθνική Στρατηγική για την Κοινωνική Ένταξη και Μείωση της Φτώχειας»
# Title:το πρότυπο agro 12 <- Ολοκλήρωση διαβούλευσης για το πρότυπο AGRO 12
# Title:το πρότυπο agro 11 <- Ολοκλήρωση δημοσίευσης ηλεκτρονικής δημόσιας διαβούλευσης για το πρότυπο AGRO 11
# Title:το πρότυπο agro 10 <- Ολοκλήρωση δημοσίευσης ηλεκτρονικής δημόσιας διαβούλευσης για το πρότυπο AGRO 10
# Title:το πρότυπο agro 9 <- Ολοκλήρωση δημοσίευσης ηλεκτρονικής δημόσιας διαβούλευσης για το πρότυπο AGRO 9
# Title:το πρότυπο agro 8 <- Ολοκλήρωση δημοσίευσης ηλεκτρονικής δημόσιας διαβούλευσης για το πρότυπο AGRO 8
# Title:εκσυγχρονισμός πλαισίου εκπαίδευσης και <- Ολοκλήρωση διαβούλευσης για το σχέδιο νόμου «Οδηγώντας με ασφάλεια: Εκσυγχρονισμός πλαισίου εκπαίδευσης και εξέτασης υποψηφίων οδηγών και οδηγών για τη χορήγηση αδειών οδήγησης οχημάτων, ρυθμίσεις για την ταξινόμηση και την κυκλοφορία οχημάτων ιστορικού ενδιαφέροντος και διατάξεις σχετικά με την οδήγηση ατόμων με αναπηρία»
# Title:για την προστασία της <- Δημόσια ηλεκτρονική διαβούλευση για το σχέδιο νόμου «Για την Προστασία της Εργασίας – Σύσταση Ανεξάρτητης Αρχής «Επιθεώρηση Εργασίας» – Κύρωση της Σύμβασης 190 της Διεθνούς Οργάνωσης Εργασίας για την εξάλειψη της βίας και παρενόχλησης στον χώρο της εργασίας – Κύρωση της Σύμβασης 187 της Διεθνούς Οργάνωσης Εργασίας για τo Πλαίσιο Προώθησης της Ασφάλειας και της Υγείας στην Εργασία – Ενσωμάτωση της Οδηγίας (ΕΕ) 2019/1158 του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου της 20ής Ιουνίου 2019 για την ισορροπία μεταξύ της επαγγελματικής και της ιδιωτικής ζωής»
# Title:oλοκλήρωση της διαδικασίας διαβούλευσης <- Oλοκλήρωση της διαδικασίας διαβούλευσης επί του Τομεακού Προγράμματος Ανάπτυξης του Υπουργείου Ψηφιακής Διακυβέρνησης
# Title:το τομεακό πρόγραμμα ανάπτυξης <- Δημόσια ηλεκτρονική διαβούλευση για το Τομεακό Πρόγραμμα Ανάπτυξης του Υπουργείου Εθνικής Άμυνας
# Title:ολοκλήρωση δημόσιας διαβούλευσης για <- Ολοκλήρωση δημόσιας διαβούλευσης για τα σχέδια προδιαγραφών που αφορούν στην παραγωγή μεταποιημένων προϊόντων Ολοκληρωμένης Διαχείρισης (πρότυπα AGRO 2-5)
# Title:νέο πλαίσιο για την <- Δημόσια ηλεκτρονική διαβούλευση για τη νομοθετική πρωτοβουλία του Υπουργείου Εσωτερικών υπό τον τίτλο «Νέο πλαίσιο για την ευζωία των ζώων συντροφιάς – Πρόγραμμα ‘‘ΆΡΓΟΣ’’»
# Title:θεσμικό πλαίσιο τηλεργασίας στον <- Ηλεκτρονική δημόσια διαβούλευση για το σχέδιο νόμου του Υπ. Εσωτερικών «Θεσμικό πλαίσιο τηλεργασίας στον δημόσιο τομέα»
# Title:προγράμματος ανάπτυξης της περιφέρειας <- Ανοιχτή δημόσια διαβούλευση Περιφερειακού Προγράμματος Ανάπτυξης της Περιφέρειας Δυτικής Ελλάδας 2021-2025
# Title:ολοκλήρωση δημόσιας διαβούλευση του <- Ολοκλήρωση δημόσιας διαβούλευση του Τομεακού Προγράμματος Ανάπτυξης (ΤΠΑ) του Υπουργείου Αγροτικής Ανάπτυξης και Τροφίμων
# Title:ολοκλήρωση δημοσίευσης διαβούλευσης – <- Ολοκλήρωση Δημοσίευσης Διαβούλευσης – Ευχαριστήριο μήνυμα κ. Υπουργού προς τους συμμετέχοντες κοινωνικούς εταίρους εν όψει της ολοκλήρωσης της δημόσιας διαβούλευσης για το Εθνικό Σχέδιο Δράσης για τις Γυναίκες, την Ειρήνη και την Ασφάλεια
# Title:περιφερειακού προγράμματος ανάπτυξης της <- Δημόσια διαβούλευση επί του Περιφερειακού Προγράμματος Ανάπτυξης της Περιφέρειας Νοτίου Αιγαίου
# Title:το τομεακό πρόγραμμα ανάπτυξης <- Δημόσια ηλεκτρονική διαβούλευση για το Τομεακό Πρόγραμμα Ανάπτυξης 2021- 2025 του Υπουργείου Υποδομών και Μεταφορών
# Title:εκλογη δημοτικων και περιφερειακων <- Σχέδιο νόμου «ΕΚΛΟΓΗ ΔΗΜΟΤΙΚΩΝ ΚΑΙ ΠΕΡΙΦΕΡΕΙΑΚΩΝ ΑΡΧΩΝ»
# Title:σύστημα εσωτερικού ελέγχου των <- Σύστημα Εσωτερικού Ελέγχου των Φορέων Γενικής Κυβέρνησης, Οργάνωση, λειτουργία και αξιολόγηση των Μονάδων Εσωτερικού Ελέγχου και λοιπές διατάξεις του Υπουργείου Εσωτερικών
# Title:αναμόρφωση θεσμικού πλαισίου της <- Δημόσια ηλεκτρονική διαβούλευση επί του σχεδίου νόμου «Αναμόρφωση θεσμικού πλαισίου της Επιτροπής Επαγγελματικού Αθλητισμού, διατάξεις εναρμόνισης με ολιστική μελέτη FIFA-UEFA για το ποδόσφαιρο και την Ελληνική Ποδοσφαιρική Ομοσπονδία, αναδιάρθρωση επαγγελματικών κατηγοριών ποδοσφαίρου και λοιπές τροποποιήσεις της αθλητικής νομοθεσίας»
# Title:το τομεακό πρόγραμμα ανάπτυξης <- Δημόσια ηλεκτρονική διαβούλευση για το τομεακό Πρόγραμμα Ανάπτυξης (ΤΠΑ) του Υπουργείου Παιδείας και Θρησκευμάτων
# Title:εισαγωγή στην τριτοβάθμια εκπαίδευση, <- Εισαγωγή στην Τριτοβάθμια Εκπαίδευση, Προστασία της Ακαδημαϊκής Ελευθερίας, Αναβάθμιση του Ακαδημαϊκού Περιβάλλοντος και άλλες διατάξεις
# Title:εθνική αρχή προσβασιμότητας, εθνική <- Εθνική Αρχή Προσβασιμότητας, Εθνική Επιτροπή για τα Δικαιώματα του Ανθρώπου και Εθνική Επιτροπή Βιοηθικής και Τεχνοηθικής
# Title:το περιφερειακό πρόγραμμα ανάπτυξης <- Ανοιχτή δημόσια διαβούλευση για το Περιφερειακό Πρόγραμμα Ανάπτυξης της Περιφέρειας Στερεάς Ελλάδας 2021-2025
# Title:ενσωμάτωση στην εθνική νομοθεσία <- Ενσωμάτωση στην εθνική νομοθεσία της τροποποιημένης με την Οδηγία (ΕΕ)2018/1808 του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου της 14ης Νοεμβρίου 2018, Οδηγίας (ΕΕ) 2010/13 του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου της 10ης Μαρτίου 2010 για τις υπηρεσίες οπτικοακουστικών μέσων και άλλες διατάξεις αρμοδιότητας της Γενικής Γραμματείας Επικοινωνίας και Ενημέρωσης
# Title:τη βίβλο ψηφιακού μετασχηματισμού <- Ανοιχτή δημόσια διαβούλευση για τη Βίβλο Ψηφιακού Μετασχηματισμού 2020-2025
# Title:διατάξεων του υπουργείου παιδείας <- Δημόσια διαβούλευση επί των διατάξεων του Υπουργείου Παιδείας και Θρησκευμάτων για την ενσωμάτωση στην ελληνική έννομη τάξη της Οδηγίας (ΕΕ) 2018/958 του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου της 28ης Ιουνίου 2018 σχετικά με τον έλεγχο αναλογικότητας πριν από τη θέσπιση νέας νομοθετικής κατοχύρωσης των επαγγελμάτων (EE L 173)
# Title:εθνικό σύστημα επαγγελματικής εκπαίδευσης, <- Εθνικό Σύστημα Επαγγελματικής Εκπαίδευσης, Κατάρτισης και Διά Βίου Μάθησης και άλλες διατάξεις
# Title:σχεδίου νόμου «ενσωμάτωση οδηγίας <- Ολοκλήρωση της δημόσιας διαβούλευσης επί του σχεδίου νόμου «Ενσωμάτωση Οδηγίας 2019/633 σχετικά με τις αθέμιτες εμπορικές πρακτικές μεταξύ επιχειρήσεων στην αλυσίδα εφοδιασμού γεωργικών προϊόντων και τροφίμων (L111/59).
# Title:βιώσιμη αστική κινητικότητα–μικροκινητικότητα-ρυθμίσεις για <- Η Ελλάδα σε κίνηση:Βιώσιμη Αστική Κινητικότητα–Μικροκινητικότητα-Ρυθμίσεις για τον εκσυγχρονισμό, την απλούστευση και την ψηφιοποίηση διαδικασιών του Υπουργείου Υποδομών και Μεταφορών
# Title:ολοκλήρωση δημοσίευσης διαβούλευσης <- Ολοκλήρωση δημοσίευσης Διαβούλευσης
# Title:ειδικό μισθολόγιο α.α.δ.ε. <- Δημόσια ηλεκτρονική διαβούλευση για το σχέδιο νόμου «Ειδικό μισθολόγιο Α.Α.Δ.Ε.»
# Title:το τομεακό πρόγραμμα ανάπτυξης <- Δημόσια ηλεκτρονική διαβούλευση για το Τομεακό Πρόγραμμα Ανάπτυξης του Υπουργείου Εργασίας
# Title:ολοκληρωμένη θαλάσσια πολιτική στο <- Ολοκληρωμένη Θαλάσσια Πολιτική στο Νησιωτικό Χώρο και λοιπές διατάξεις
# Title:eκσυγχρονισμός, αναδιοργάνωση του ταμείου <- Δημόσια ηλεκτρονική διαβούλευση επί του σχεδίου νόμου με τίτλο: «Eκσυγχρονισμός, αναδιοργάνωση του Ταμείου Αρχαιολογικών Πόρων και Απαλλοτριώσεων και μετονομασία του σε Οργανισμό Ανάπτυξης και Διαχείρισης Πολιτιστικών Πόρων (Ο.Δ.Α.Π.), ίδρυση ν.π.ι.δ. με την επωνυμία «Μουσείο- Ελαιοτριβείο Βρανά» στο Δήμο Λέσβου, και λοιπές ρυθμίσεις του Υπουργείου Πολιτισμού και Αθλητισμού»
# Title:μέτρα ενίσχυσης των εργαζομένων <- «Μέτρα ενίσχυσης των εργαζομένων και ευάλωτων κοινωνικών ομάδων, κοινωνικοασφαλιστικές διατάξεις και διατάξεις για την ενίσχυση των ανέργων»
# Title:ολοκλήρωση δημοσίευσης διαβούλευσης <- Ολοκλήρωση δημοσίευσης διαβούλευσης
# Title:ρυθμίσεις σωφρονιστικής νομοθεσίας και <- Ρυθμίσεις Σωφρονιστικής νομοθεσίας και λοιπές διατάξεις Υπουργείου Προστασίας του Πολίτη
# Title:εθνικό σχέδιο δράσης για <- Εθνικό Σχέδιο Δράσης για τα Δικαιώματα των Ατόμων με Αναπηρία
# Title:τροποποίηση του ν.4557/2018 (α΄139) <- Τροποποίηση του ν.4557/2018 (Α΄139) για την πρόληψη και καταστολή της νομιμοποίησης εσόδων από εγκληματικές δραστηριότητες και της χρηματοδότησης της τρομοκρατίας- Ενσωμάτωση της Οδηγίας (ΕΕ) 2018/843
# Title:τροποποίηση κώδικα ελληνικής ιθαγένειας, <- Τροποποίηση Κώδικα Ελληνικής Ιθαγένειας, νέο πλαίσιο επιλογής στελεχών στον δημόσιο τομέα, οργανωτικές διατάξεις Υπουργείου Εσωτερικών και διατάξεις για την αναπτυξιακή προοπτική των ΟΤΑ
# Title:κώδικας διευθέτησης οφειλών και <- Κώδικας Διευθέτησης Οφειλών και Παροχής Δεύτερης Ευκαιρίας
# Title:σύσταση, λειτουργία και αρμοδιότητες <- Διαβούλευση για το σχέδιο νόμου «Σύσταση, λειτουργία και αρμοδιότητες Αρχής Πολιτικής Αεροπορίας και ρύθμιση ζητημάτων Υπηρεσίας Πολιτικής Αεροπορίας»
# Title:οργάνωση και λειτουργία υπουργείου <- Διαβούλευση για το σχέδιο νόμου «Οργάνωση και Λειτουργία Υπουργείου Εξωτερικών»
# Title:αναμόρφωση θεσμικού πλαισίου των <- Διαβούλευση επί του σχεδίου νόμου «Αναμόρφωση θεσμικού πλαισίου των αρχαιρεσιών των αθλητικών φορέων, διακρινόμενοι συνοδοί αθλητών ΑμεΑ, σύσταση Εθνικής Πλατφόρμας Αθλητικής Ακεραιότητας, Ελληνική Ολυμπιακή Επιτροπή (Ε.Ο.Ε.), Ελληνική Παραολυμπιακή Επιτροπή (Ε.Π.Ε.) και άλλες διατάξεις»
# Title:κώδικα ψηφιακής διακυβέρνησης <- Ολοκλήρωση δημόσιας διαβούλευσης για τις διατάξεις που αφορούν στον «Κώδικα Ψηφιακής Διακυβέρνησης»
# Title:εκσυγχρονισμός της ιδιωτικής εκπαίδευσης <- Ολοκλήρωση Δημοσίευσης Διαβούλευσης επί του σχεδίου νόμου με τίτλο «Εκσυγχρονισμός της Ιδιωτικής Εκπαίδευσης και άλλες διατάξεις»
# Title:φορολογικές παρεμβάσεις για την <- Ολοκλήρωση διαβούλευσης για το σχ/ν «Φορολογικές παρεμβάσεις για την ενίσχυση της αναπτυξιακής διαδικασίας της ελληνικής οικονομίας, ενσωμάτωση στην Ελληνική Νομοθεσία των Οδηγιών  (ΕΕ) 2017/1852, (ΕΕ) 2018/822, (ΕΕ) 2020/876, (ΕΕ) 2016/1164, (ΕΕ) 2018/1910 και (ΕΕ) 2019/475 και άλλες διατάξεις»
# Title:διασφάλιση της πρόσβασης σε <- Διαβούλευση επί του σχεδίου νόμου: «Ρυθμίσεις για τη διασφάλιση της πρόσβασης σε ποιοτικές υπηρεσίες υγείας και ίδρυση του Οργανισμού Διασφάλισης της Ποιότητας στην Υγεία Α.Ε. (ΟΔΙΠΥ Α.Ε.)»
του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου της 13ης Σεπτεμβρίου 2017 σχετικά με ορισμένες επιτρεπόμενες χρήσεις ορισμένων προστατευόμενων έργων και άλλων αντικειμένων προστασίας δυνάμει δικαιωμάτων πνευματικής ιδιοκτησίας και συγγενικών δικαιωμάτων προς όφελος των τυφλών, των αμβλυώπων και των ατόμων με άλλα προβλήματα ανάγνωσης εντύπων και για την τροποποίηση της Οδηγίας 2001/29/ΕΚ για την εναρμόνιση ορισμένων πτυχών του δικαιώματος του δημιουργού και συγγενικών δικαιωμάτων στην κοινωνία της πληροφορίας»
# Title:ρύθμιση θεμάτων υπουργείου εσωτερικών <- Σχέδιο Νόμου «Ρύθμιση Θεμάτων Υπουργείου Εσωτερικών»
# Title:ενσωμάτωση στην ελληνική νομοθεσία <- Ενσωμάτωση στην ελληνική νομοθεσία της Οδηγίας (EE) 2016/2341 του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου της 14ης Δεκεμβρίου 2016 για τις δραστηριότητες και την εποπτεία των ιδρυμάτων επαγγελματικών συνταξιοδοτικών παροχών (Ι.Ε.Σ.Π.).
# Title:διευκολυνση ασκησης εκλογικου δικαιωματος <- ΣΧΕΔΙΟ ΝΟΜΟΥ «ΔΙΕΥΚΟΛΥΝΣΗ ΑΣΚΗΣΗΣ ΕΚΛΟΓΙΚΟΥ ΔΙΚΑΙΩΜΑΤΟΣ ΕΚΛΟΓΕΩΝ ΠΟΥ ΒΡΙΣΚΟΝΤΑΙ ΕΚΤΟΣ ΕΛΛΗΝΙΚΗΣ ΕΠΙΚΡΑΤΕΙΑΣ»
# Title:φορολογικη μεταρρυθμιση με αναπτυξιακη <- ΣΧΕΔΙΟ ΝΟΜΟΥ «ΦΟΡΟΛΟΓΙΚΗ ΜΕΤΑΡΡΥΘΜΙΣΗ ΜΕ ΑΝΑΠΤΥΞΙΑΚΗ ΔΙΑΣΤΑΣΗ ΓΙΑ ΤΗΝ ΕΛΛΑΔΑ ΤΟΥ ΑΥΡΙΟ»
# Title:τροποποιηση εκλογικης διαδικασιας και <- ΤΡΟΠΟΠΟΙΗΣΗ ΕΚΛΟΓΙΚΗΣ ΔΙΑΔΙΚΑΣΙΑΣ ΚΑΙ ΑΛΛΕΣ ΔΙΑΤΑΞΕΙΣ
# Title:την αποχώρηση του ηνωμένου <- Επείγουσες ρυθμίσεις για την αποχώρηση του Ηνωμένου Βασιλείου από την Ευρωπαϊκή Ένωση
# Title:σχέδιο νόμου περί διεθνούς <- Σχέδιο Νόμου Περί Διεθνούς Προστασίας
# Title:κύρωση της σύμβασης magglingen/macolin <- Κύρωση της Σύμβασης Magglingen/Macolin σχετικά με τη χειραγώγηση των αθλητικών αγώνων, επείγοντα μέτρα για την αντιμετώπιση της βίας στον αθλητισμό και άλλες διατάξεις
# Title:κανονισμός τιμολόγησης των φοδσα <- Κανονισμός Τιμολόγησης των ΦΟΔΣΑ και Ρυθμίσεις για την ενίσχυση της κυκλικής οικονομίας
# Title:χαρακτηρισμός της υδάτινης, χερσαίας <- Χαρακτηρισμός της υδάτινης, χερσαίας και ευρύτερης περιοχής της λίμνης Παμβώτιδας (Ιωαννίνων),Π.Ε. Ιωαννίνων ως Περιφερειακό Πάρκο, και καθορισμός χρήσεων γης, όρων και περιορισμών δόμησης
# Title:ενδυναμωση ανωτατου συμβουλιου επιλογης <- ΕΝΔΥΝΑΜΩΣΗ ΑΝΩΤΑΤΟΥ ΣΥΜΒΟΥΛΙΟΥ ΕΠΙΛΟΓΗΣ ΠΡΟΣΩΠΙΚΟΥ (Α.Σ.Ε.Π.), ΕΝΙΣΧΥΣΗ ΚΑΙ ΑΝΑΒΑΘΜΙΣΗ ΔΗΜΟΣΙΑΣ ΔΙΟΙΚΗΣΗΣ ΚΑΙ ΑΛΛΕΣ ΔΙΑΤΑΞΕΙΣ
# Title:περιβαλλοντική διαχείριση των περιοχών <- Περιβαλλοντική διαχείριση των περιοχών με οικιστικές πυκνώσεις, ιώδους περιγράμματος
# Title:νόμος για την προσέλκυση <- Νόμος για την προσέλκυση Στρατηγικών Επενδύσεων
# Title:δημόσιες συμβάσεις προμηθειών, υπηρεσιών <- Δημόσιες συμβάσεις προμηθειών, υπηρεσιών και έργων στους τομείς της άμυνας και της ασφάλειας
# Title:επιτροπή επαγγελματικού αθλητισμού – <- Επιτροπή επαγγελματικού αθλητισμού – Προπονητές και εκπαιδευτές – Ιδιωτικά γυμναστήρια και ιδιωτικές σχολές εκμάθησης αθλημάτων και άλλες διατάξεις
# Title:πρόσβαση των ατόμων με <- Πρόσβαση των ατόμων με αναπηρία, στις υπηρεσίες των παρόχων υπηρεσιών μέσων μαζικής ενημέρωσης και επικοινωνίας
# Title:ρύθμιση θεμάτων που αφορούν <- Τροποποίηση διατάξεων του ν. 2168/1993 (Α΄ 147) «Ρύθμιση θεμάτων που αφορούν όπλα, πυρομαχικά, εκρηκτικές ύλες, εκρηκτικούς μηχανισμούς και άλλες διατάξεις»
# Title:εθνικός σχεδιασμός για την <- Εθνικός Σχεδιασμός για την Ενέργεια και το Κλίμα
# Title:διαδικασιες κανονιστικου ελεγχου πρακτικων <- ΔΙΑΔΙΚΑΣΙΕΣ ΚΑΝΟΝΙΣΤΙΚΟΥ ΕΛΕΓΧΟΥ ΠΡΑΚΤΙΚΩΝ ΙΟΝΤΙΖΟΥΣΩΝ ΑΚΤΙΝΟΒΟΛΙΩΝ – ΑΝΑΓΝΩΡΙΣΗ ΥΠΗΡΕΣΙΩΝ ΚΑΙ ΕΜΠΕΙΡΟΓΝΩΜΟΝΩΝ
# Title:προσαρμογή της ελληνικής νομοθεσίας <- Προσαρμογή της ελληνικής νομοθεσίας στις διατάξεις της Οδηγίας 2016/2102 του Ευρωπαϊκού Κοινοβουλίου για την προσβασιμότητα των ιστότοπων
# Title:κύρωση των συμβάσεων παραχώρησης <- Κύρωση των Συμβάσεων Παραχώρησης που συνήφθησαν μεταξύ του Ελληνικού Δημοσίου και των Οργανισμών Λιμένων Α.Ε. και άλλες διατάξεις
# Title:εναρμόνιση νομοθετικού πλαισίου για <- Εναρμόνιση νομοθετικού πλαισίου για την έκδοση ηλεκτρονικών τιμολογίων στο πλαίσιο Δημοσίων Συμβάσεων.
# Title:aδειοδότηση και έλεγχος κατασκευών <- Aδειοδότηση και Έλεγχος Κατασκευών Κεραιών στην Ξηρά
# Title:περί εταιρικών μετασχηματισμών <- Σχέδιο νόμου «Περί εταιρικών μετασχηματισμών»
# Title:σύσταση ελληνικής αρχής γεωλογικών <- Σύσταση Ελληνικής Αρχής Γεωλογικών και Μεταλλευτικών Ερευνών
# Title:πανεπιστήμιο θεσσαλίας, εθνικό και <- Πανεπιστήμιο Θεσσαλίας, Εθνικό και Καποδιστριακό Πανεπιστήμιο Αθηνών, Γεωπονικό Πανεπιστήμιο Αθηνών, Παλλημνιακό Ταμείο και άλλες διατάξεις
# Title:τεχνικές προδιαγραφές για την <- «Τεχνικές Προδιαγραφές για την προμήθεια οχημάτων ειδικής χρήσης»
# Title:τεχνικές προδιαγραφές για την <- Τεχνικές προδιαγραφές για την προμήθεια συστημάτων αναγνώρισης πινακίδων οχημάτων που διέρχονται από τα νομοθετημένα συνοριακά σημεία διέλευσης της χώρας
# Title:κατηγοριοποίηση παραβάσεων του άρθρου <- Κατηγοριοποίηση παραβάσεων του άρθρου 19Α του ν.4062/2012 και όρια προστίμων
# Title:τεχνικές προδιαγραφές για την <- Τεχνικές Προδιαγραφές για την προμήθεια επιβατικών αυτοκινήτων διπλού καυσίμου Ελληνικής Αστυνομίας
# Title:αγορά διαδικτυακών παιγνίων- τροποποίηση <- Ρυθμίσεις για την αγορά διαδικτυακών παιγνίων- Τροποποίηση του ν. 4002/2011
# Title:εθνικό σχέδιο για την <- Εθνικό Σχέδιο για την αύξηση του αριθμού των κτιρίων με σχεδόν μηδενική κατανάλωση ενέργειας (άρθρο 9 της Οδηγίας 2010/31/ΕΕ)
# Title:τεχνικές προδιαγραφές για την <- Τεχνικές Προδιαγραφές για την προμήθεια Οχημάτων Ειδικής Χρήσης & Γερανοφόρων Οχημάτων Ελληνικής Αστυνομίας
# Title:δικονομικοί κανόνες επί υποθέσεων <- Δικονομικοί κανόνες επί υποθέσεων δικαιοδοσίας Μουφτή-Σύσταση, οργάνωση και λειτουργία Διεύθυνσης Υποθέσεων Δικαιοδοσίας Μουφτή στις Μουφτείες
# Title:σχέδιο στρατηγικής ανάπτυξης της <- Σχέδιο Στρατηγικής Ανάπτυξης της Δασοπονίας 2018-2038 (Εθνική Στρατηγική για τα Δάση)
# Title:ίδρυση και λειτουργία κτηνοτροφικών <- Ρυθμίσεις για την  ίδρυση και λειτουργία κτηνοτροφικών εγκαταστάσεων
# Title:κωδικας οδοντιατρων <- ΚΩΔΙΚΑΣ ΟΔΟΝΤΙΑΤΡΩΝ
# Title:σύσταση εθνικού οργανισμού δημόσιας <- Σύσταση Εθνικού Οργανισμού Δημόσιας Υγείας και Εθνικού Ινστιτούτου Νεοπλασιών
# Title:εξυγίανση του ταμείου αλληλοβοήθειας <- Εξυγίανση του Ταμείου Αλληλοβοήθειας Υπαλλήλων Υπουργείου Πολιτισμού και Αθλητισμού  και άλλες διατάξεις
# Title:εφαρμογή διατάξεων του κανονισμού <- Εφαρμογή διατάξεων του Κανονισμού (ΕΕ) 2017/1939 του Συμβουλίου της 12ης Οκτωβρίου 2017, σχετικά με την εφαρμογή ενισχυμένης συνεργασίας για τη σύσταση της Ευρωπαϊκής Εισαγγελίας
# Title:διαδικασία καθορισμού, οριοθέτησης και <- Διαδικασία καθορισμού, οριοθέτησης και οργάνωσης, των απαιτούμενων δικαιολογητικών, του τρόπου λειτουργίας και διαχείρισης του Επιχειρηματικού Πάρκου Μεμονωμένης Μεγάλης Μονάδας (ΕΠΜΜΜ)
# Title:έρευνα, εκμετάλλευση και διαχείριση <- Έρευνα, εκμετάλλευση και διαχείριση του γεωθερμικού δυναμικού της χώρας και άλλες διατάξεις
# Title:ίδρυση υπηρεσίας  δικαστικής <- Ίδρυση Υπηρεσίας  Δικαστικής  Αστυνομίας
# Title:η δικονομία του ελεγκτικού <- Η Δικονομία του Ελεγκτικού Συνεδρίου
# Title:περι οργανισμων εναλλακτικων επενδυσεων <- ΠΕΡΙ ΟΡΓΑΝΙΣΜΩΝ ΕΝΑΛΛΑΚΤΙΚΩΝ ΕΠΕΝΔΥΣΕΩΝ  (ΟΕΕ)  ΜΕ ΜΟΡΦΗ ΑΜΟΙΒΑΙΟΥ ΚΕΦΑΛΑΙΟΥ
# Title:χαρακτηρισμός χερσαίων, υδάτινων και <- Χαρακτηρισμός χερσαίων, υδάτινων και θαλάσσιων περιοχών ως Εθνικού Πάρκου
# Title:εναρμόνιση της νομοθεσίας με <- Εναρμόνιση της νομοθεσίας με την Οδηγία 2016/97 /ΕΕ του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου της 20ης  Ιανουαρίου 2016 σχετικά με τη διανομή ασφαλιστικών προϊόντων.
# Title:εθνικό ταμείο δίκαιης μετάβασης <- Εθνικό Ταμείο Δίκαιης Μετάβασης
# Title:ετησια εκθεση 2018 για <- ΕΤΗΣΙΑ ΕΚΘΕΣΗ 2018 ΓΙΑ ΤΗ ΔΙΑΘΕΣΗ ΚΑΙ ΠΕΡΑΙΤΕΡΩ ΧΡΗΣΗ ΤΩΝ ΑΝΟΙΚΤΩΝ ΔΕΔΟΜΕΝΩΝ
# Title:εκσυγχρονισμός και αναμόρφωση θεσμικού <- Σχέδιο Νόμου: «Εκσυγχρονισμός και Αναμόρφωση Θεσμικού Πλαισίου Ιδιωτικών Κλινικών»
# Title:θεματικός τουρισμός – ειδικές <- Θεματικός τουρισμός – Ειδικές μορφές τουρισμού
# Title:ιόνιο πανεπιστήμιο <- Ιόνιο Πανεπιστήμιο
# Title:ασφαλιστικές και συνταξιοδοτικές ρυθμίσεις, <- Ασφαλιστικές και συνταξιοδοτικές ρυθμίσεις, Αντιμετώπιση της αδήλωτης εργασίας
# Title:πρόσβαση των μόνιμων κατοίκων <- Παράρτημα του σ.ν. με τίτλο «Πρόσβαση των μόνιμων κατοίκων των περιοχών εκτός κάλυψης της ελληνικής Επικράτειας στους ελληνικούς τηλεοπτικούς σταθμούς ελεύθερης λήψης εθνικής εμβέλειας»
# Title:εθνική στρατηγική για την <- Εθνική Στρατηγική για την Κυκλική Οικονομία
# Title:περί ανωνύμων εταιρειών <- Περί Ανωνύμων Εταιρειών
# Title:διοικούσα επιτροπή ισλαμικού τεμένους <- Οργανισμός Λειτουργίας του Ν.Π.Ι.Δ. «Διοικούσα Επιτροπή Ισλαμικού Τεμένους Αθηνών»
# Title:πανεπιστήμιο ιωαννίνων <- Πανεπιστήμιο Ιωαννίνων
# Title:τεχνικές προδιαγραφές για την <- Τεχνικές Προδιαγραφές για την προμήθεια συστήματος τυποποιημένου εξοπλισμού για τον έλεγχο ταχογράφων οχημάτων και συσκευών ανίχνευσης αλκοόλης
# Title:κλεισθενης ι <- Πρόγραμμα «ΚΛΕΙΣΘΕΝΗΣ Ι»
# Title:ενσωμάτωση στην ελληνική νομοθεσία <- Ενσωμάτωση στην ελληνική νομοθεσία της οδηγίας 2015/637/ΕΕ του Συμβουλίου της 20ης Απριλίου 2015
# Title:στρατηγικό πλαίσιο για τον <- Στρατηγικό Πλαίσιο για τον Ανασχεδιασμό των Ενεργητικών Πολιτικών Απασχόλησης
# Title:μηχανισμός εφαρμογής, κρατική εποπτεία <- Μηχανισμός Εφαρμογής, Κρατική Εποπτεία και Γενικοί Όροι Υλοποίησης του Μεταφορικού Ισοδύναμου (Μ.Ι.) και άλλες διατάξεις
# Title:τροποποίηση του ν. 3251/2004 <- Τροποποίηση του ν. 3251/2004 “Ευρωπαϊκό ένταλμα σύλληψης, τροποποίηση του ν. 2928/2001 για τις εγκληματικές οργανώσεις και άλλες διατάξεις”
# Title:ενσωμάτωση της οδηγίας (εε) <- Ενσωμάτωση της Οδηγίας (ΕΕ) 2016/343 για την ενίσχυση ορισμένων πτυχών του τεκμηρίου αθωότητας και του δικαιώματος παράστασης του κατηγορουμένου στη δίκη του στο πλαίσιο ποινικής διαδικασίας
# Title:κατάρτιση εθνικού καταλόγου γεγονότων <- Κατάρτιση εθνικού καταλόγου γεγονότων μείζονος σημασίας στα οποία το κοινό θα έχει δωρεάν τηλεοπτική πρόσβαση
# Title:αναδιοργάνωση των δομών υποστήριξης <- Αναδιοργάνωση των δομών υποστήριξης της πρωτοβάθμιας και δευτεροβάθμιας εκπαίδευσης και άλλες διατάξεις
# Title:ονομαστικά αρχεία επιβατών, ίδρυση <- Ονομαστικά αρχεία επιβατών, ίδρυση και λειτουργία Μονάδας Στοιχείων Επιβατών – Ενσωμάτωση στην ελληνική νομοθεσία της Οδηγίας (EE) 2016/681 (EE L 119 της 4/5/2016 σ.132-149
# Title:ενισχύσεις καινοτομικού χαρακτήρα για <- «Ενισχύσεις Καινοτομικού Χαρακτήρα για ΜΜΕ» του Αναπτυξιακού νόμου 4399/16
# Title:συνέργειες και δικτυώσεις <- «Συνέργειες και Δικτυώσεις»  του Αναπτυξιακού νόμου 4399/2016
# Title:προώθηση της ουσιαστικής ισότητας <- Προώθηση της ουσιαστικής ισότητας των φύλων και την καταπολέμηση της έμφυλης βίας
# Title:τηλεοπτική κάλυψη στο σύνολο <- Τηλεοπτική κάλυψη στο σύνολο της ελληνικής επικράτειας μέσω της εξασφάλισης της πρόσβασης των μόνιμων κατοίκων των περιοχών εκτός κάλυψης στους ελληνικούς τηλεοπτικούς σταθμούς ελεύθερης λήψης και εθνικής εμβέλειας
# Title:νόμος για την προστασία <- Νόμος για την Προστασία Δεδομένων Προσωπικού Χαρακτήρα σε εφαρμογή του Κανονισμού (ΕΕ) 2016/679
# Title:προληψη και καταστολη της <- ΠΡΟΛΗΨΗ ΚΑΙ ΚΑΤΑΣΤΟΛΗ ΤΗΣ ΝΟΜΙΜΟΠΟΙΗΣΗΣ ΕΣΟΔΩΝ ΑΠΟ ΕΓΚΛΗΜΑΤΙΚΕΣ ΔΡΑΣΤΗΡΙΟΤΗΤΕΣ ΚΑΙ ΤΗΣ ΧΡΗΜΑΤΟΔΟΤΗΣΗΣ ΤΗΣ ΤΡΟΜΟΚΡΑΤΙΑΣ
# Title:ελληνικος οργανισμος αγροτικης ερευνας, <- ΕΛΛΗΝΙΚΟΣ ΟΡΓΑΝΙΣΜΟΣ ΑΓΡΟΤΙΚΗΣ ΕΡΕΥΝΑΣ, ΕΚΠΑΙΔΕΥΣΗΣ ΚΑΙ ΑΝΑΠΤΥΞΗΣ (ΕΛΓΟ)
# Title:τεχνικές προδιαγραφές για προμήθειες <- Τεχνικές Προδιαγραφές για Προμήθειες της Ελληνικής Αστυνομίας
# Title:εκσυγχρονισμό του θεσμικού πλαισίου <- Ρυθμίσεις για τον εκσυγχρονισμό του θεσμικού πλαισίου οργάνωσης και λειτουργίας των Φορέων Διαχείρισης Στερεών Αποβλήτων της χώρας
# Title:κύρωση και προσαρμογή της <- Κύρωση και προσαρμογή της ελληνικής νομοθεσίας προς τις διατάξεις της  Σύμβασης της Χάγης της 13ης Ιανουαρίου 2000 για τη Διεθνή Προστασία Ενηλίκων
# Title:τεχνικές προδιαγραφές για την <- Τεχνικές Προδιαγραφές για την προμήθεια συσσωρευτών αυτοκινήτων, λεωφορείων, φορτηγών και δίκυκλων μοτοσικλετών οχημάτων Ελληνικής Αστυνομίας
# Title:μεταρρύθμιση του θεσμού της <- Μεταρρύθμιση του θεσμού της διαμεσολάβησης
# Title:τροποποίηση του ν.3190/1955 περί <- Τροποποίηση του ν.3190/1955 περί εταιρειών περιορισμένης ευθύνης
# ...
# Title:κ. μητσοτάκης, ε. κουτμερίδης <- Αντιμετώπιση της φοροδιαφυγής και άλλες διατάξεις.
# ΕΙΣΗΓΗΤΕΣ: Κ. Μητσοτάκης, Ε. Κουτμερίδης
# Title:κ. μητσοτάκης, ε. κουτμερίδης <- Αντιμετώπιση της φοροδιαφυγής και άλλες διατάξεις.
# ΕΙΣΗΓΗΤΕΣ: Κ. Μητσοτάκης, Ε. Κουτμερίδης
# Title:αναπροσαρμογή των τελών κυκλοφορίας <- Κύρωση και τροποποίηση της από 2.11.2009 Πράξης Νομοθετικού Περιεχομένου «Αναπροσαρμογή των τελών κυκλοφορίας οχημάτων και κατάργηση του μέτρου απόσυρσης οχημάτων καθώς και διατάξεων της από 16.9.2009 Πράξης Νομοθετικού Περιεχομένου «Μέτρα για την Αντιμετώπιση της Ατμοσφαιρικής Ρύπανσης» (ΦΕΚ 181 Α΄), όπως αυτή διορθώθηκε με τη «Διόρθωση Σφαλμάτων», που δημοσιεύτηκε στο ΦΕΚ 222 Α΄»».
#
# Title:ενσωμάτωση α) της οδηγίας <- Ενσωμάτωση α) της Οδηγίας (ΕΕ) 2019/2162 του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου της 27ης Νοεμβρίου 2019 σχετικά με την έκδοση καλυμμένων ομολόγων και τη δημόσια εποπτεία
# καλυμμένων ομολόγων και την τροποποίηση των Οδηγιών 2009/65/ ΕΚ και 2014/59/ΕΕ, β) της Οδηγίας (ΕΕ) 2019/1153 του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου για τη θέσπιση
# κανόνων με σκοπό τη διευκόλυνση της χρήσης χρηματοοικονομικών και άλλων πληροφοριών για την πρόληψη, την ανίχνευση, τη διερεύνηση ή τη δίωξη ορισμένων ποινικών αδικημάτων και την
# κατάργηση της Απόφασης 2000/642/ΔΕΥ του Συμβουλίου, γ) της Οδηγίας (ΕΕ) 2019/2034 σχετικά με την προληπτική εποπτεία επιχειρήσεων επενδύσεων, την τροποποίηση των Οδηγιών
# 2002/87/ ΕΚ, 2009/65/ΕΚ, 2011/61/ΕΕ, 2013/36/ΕΕ, 2014/59/ ΕΕ και 2014/65/ΕΕ και την προσαρμογή στον Κανονισμό (ΕΕ) 2019/2033 σχετικά με τις απαιτήσεις προληπτικής
# εποπτείας επιχειρήσεων επενδύσεων και την τροποποίηση των Kανονισμών (ΕΕ) 1093/2010, (ΕΕ) 575/2013, (ΕΕ) 600/2014 και (ΕΕ) 806/2014, δ) του άρθρου 1 της Οδηγίας (ΕΕ)
# 2019/2177 για την τροποποίηση της Οδηγίας 2014/65/ΕΕ για τις αγορές χρηματοπιστωτικών μέσων,ε) της Oδηγίας (ΕΕ) 2020/1504 για την τροποποίηση της Οδηγίας 2014/65/ΕΕ για τις
# αγορές χρηματοπιστωτικών μέσων και την προσαρμογή στον Κανονισμό (ΕΕ) 2020/1503 σχετικά με τους Ευρωπαίους παρόχους υπηρεσιών συμμετοχικής χρηματοδότησης για επιχειρήσεις, στ) της
# Οδηγίας (ΕΕ) 2019/1160 για την τροποποίηση των Οδηγιών 2009/65/ΕΚ και 2011/61/ΕΕ όσον αφορά τη διασυνοριακή διανομή οργανισμών συλλογικών επενδύσεων,ζ) της Οδηγίας (ΕΕ)
# 2021/338 του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου της
Οδηγίας 2012/27/ΕΕ του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου της 25ης Οκτωβρίου 2012 «Για την ενεργειακή απόδοση, την τροποποίηση των Οδηγιών 2009/125/ΕΚ και 2010/30/ΕΕ και την κατάργηση των Οδηγιών 2004/8/ΕΚ και 2006/32/ΕΚ», όπως τροποποιήθηκε από την Οδηγία 2013/12/ΕΕ του Συμβουλίου της 13ης Μαΐου 2013 «Για την προσαρμογή της Οδηγίας 2012/27/ΕΕ του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου για την ενεργειακή απόδοση, λόγω της προσχώρησης της Δημοκρατίας της Κροατίας» και άλλες διατάξεις.
# Title:έκδοση διαταγής πληρωμής για <- Έκδοση διαταγής πληρωμής για αξιώσεις από διοικητική σύμβαση που έχει συναφθεί στο πλαίσιο εμπορικής
# συναλλαγής και άλλες διατάξεις.
# Title:ελληνικά λογιστικά πρότυπα και <- Ελληνικά Λογιστικά Πρότυπα και συναφείς ρυθμίσεις.
# Title:έκδοση διαταγής πληρωμής για <- Έκδοση διαταγής πληρωμής για αξιώσεις από διοικητική σύμβαση που έχει συναφθεί στο πλαίσιο εμπορικής
# συναλλαγής και άλλες διατάξεις.
# Title:ενιαίο ρυθμιστικό πλαίσιο για <- Ενιαίο ρυθμιστικό πλαίσιο για την οργάνωση και λειτουργία του Ελληνικού Γεωργικού Οργανισμού - ΔΗΜΗΤΡΑ, σύσταση και λειτουργία φορέα διαχείρισης Παραδοσιακού Ελαιώνα Άμφισσας και άλλες διατάξεις για την ενίσχυση της αγροτικής ανάπτυξης
# Title:εκσυγχρονισμός του δικαίου ανταγωνισμού <- Εκσυγχρονισμός του δικαίου ανταγωνισμού για την ψηφιακή εποχή - Τροποποίηση του ν. 3959/2011 και
# ενσωμάτωση της Οδηγίας (ΕΕ) 2019/1 του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου της 11ης Δεκεμβρίου
# 2018 για την παροχή αρμοδιοτήτων στις αρχές ανταγωνισμού των κρατών μελών ώστε να επιβάλλουν
# αποτελεσματικότερα τους κανόνες και για τη διασφάλιση της εύρυθμης λειτουργίας της εσωτερικής αγοράς
# Title:για την ενεργειακή απόδοση, <- Συνταξιοδοτικές ρυθμίσεις, ενσωμάτωση στο Ελληνικό Δίκαιο της Οδηγίας 2012/27/ΕΕ του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου της 25ης Οκτωβρίου 2012 «Για την ενεργειακή απόδοση, την τροποποίηση των Οδηγιών 2009/125/ΕΚ και 2010/30/ΕΕ και την κατάργηση των Οδηγιών 2004/8/ΕΚ και 2006/32/ΕΚ», όπως τροποποιήθηκε από την Οδηγία 2013/12/ΕΕ του Συμβουλίου της 13ης Μαΐου 2013 «Για την προσαρμογή της Οδηγίας 2012/27/ΕΕ του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου για την ενεργειακή απόδοση, λόγω της προσχώρησης της Δημοκρατίας της Κροατίας» και άλλες διατάξεις.
# Title:για την ενεργειακή απόδοση, <- Συνταξιοδοτικές ρυθμίσεις, ενσωμάτωση στο Ελληνικό Δίκαιο της Οδηγίας 2012/27/ΕΕ του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου της
# δικαιοσύνης, άλλες τροποποιήσεις στον Κώδικα Πολιτικής Δικονομίας και λοιπές επείγουσες διατάξεις.
# Title:φάροι, στρατολογία και άλλες <- Φάροι, Στρατολογία και άλλες διατάξεις.
# Title:αρχές και κανόνες για <- Αρχές και κανόνες για την εξυγίανση της λειτουργίας και την ανάπτυξη βασικών τομέων του εμπορίου και της αγοράς - Θέματα  Υπουργείου Ανάπτυξης
# Title:εταιρεία συστήματος αμοιβών νοσοκομείων <- Γενικές διατάξεις για τη δημιουργία συστήματος αμοιβών νοσοκομείων − σύσταση και καταστατικό της εταιρείας με την επωνυμία «Εταιρεία συστήματος αμοιβών νοσοκομείων ανώνυμη εταιρεία» − Προσαρμογή στο Εθνικό Δίκαιο της Οδηγίας 2012/39/ΕΕ της επιτροπής της 26ης Νοεμβρίου 2012 για την τροποποίηση της Οδηγίας 2006/17/ΕΚ και λοιπές διατάξεις
# Title:κ. μητσοτάκης, ε. κουτμερίδης <- Αντιμετώπιση της φοροδιαφυγής και άλλες διατάξεις.
# ΕΙΣΗΓΗΤΕΣ: Κ. Μητσοτάκης, Ε. Κουτμερίδης
# Title:i) κύρωση και προσαρμογή <- I) Κύρωση και προσαρμογή της ελληνικής νομοθεσίας στη Σύμβαση της Βαρσοβίας της 16ης Μαΐου 2005 του
# Συμβουλίου της Ευρώπης για τη νομιμοποίηση, ανίχνευση, κατάσχεση και δήμευση εσόδων από εγκληματικές
# δραστηριότητες και
# για τη χρηματοδότηση της τρομοκρατίας, ενσωμάτωση της Α-Π 2003/577/ΔΕΥ, της Α-Π 2005/212/ΔΕΥ, της
# Α-Π 2006/783/ΔΕΥ, όπως τροποποιήθηκε με την Α-Π 2009/299/ΔΕΥ, και της Οδηγίας 2014/42/ΕΕ, II)
# Προϋποθέσεις
# τοποθέτησης ανηλίκων σε ίδρυμα ή ανάδοχη οικογένεια από και προς κράτη - μέλη της Ευρωπαϊκής Ένωσης
# βάσει του άρθρου 56 του Κανονισμού (ΕΚ) αριθμ. 2201/2003 του Συμβουλίου της 27ης Νοεμβρίου 2003, για
# τη διεθνή
# δικαιοδοσία και την αναγνώριση και εκτέλεση αποφάσεων σε γαμικές διαφορές και διαφορές γονικής μέριμνας, ο
# οποίος καταργεί τον Κανονισμό (ΕΚ) 1347/2000, III) Ενσωμάτωση της Οδηγίας 2013/48/ΕΕ του Ευρωπαϊκού
# Κοινοβουλίου
# και του Συμβουλίου της 22ας Οκτωβρίου 2013, σχετικά με το δικαίωμα πρόσβασης σε δικηγόρο στο πλαίσιο
# ποινικής διαδικασίας και διαδικασίας εκτέλεσης του ευρωπαϊκού εντάλματος σύλληψης, καθώς και σχετικά με το
# δικαίωμα
# ενημέρωσης τρίτου προσώπου σε περίπτωση στέρησης της ελευθερίας του και με το δικαίωμα επικοινωνίας με
# τρίτα πρόσωπα και με προξενικές αρχές κατά τη διάρκεια στέρησης της ελευθερίας, IV) Ενσωμάτωση της
# Οδηγίας 2012/29/ΕΕ
# για τη θέσπιση ελάχιστων προτύπων σχετικά με τα δικαιώματα, την υποστήριξη και την προστασία θυμάτων της
# εγκληματικότητας και για την αντικατάσταση της Απόφασης - Πλαίσιο 2001/220/ΔΕΥ του Συμβουλίου και
# λοιπές διατάξεις.
# Title:ε. ράπτη, θ. δραγώνα <- Ειδική Αγωγή και Εκπαίδευση ατόμων με αναπηρία ή με ειδικές εκπαιδευτικές ανάγκες ΕΙΣΗΓΗΤΕΣ: Ε. Ράπτη, Θ. Δραγώνα
# Title:άσκηση εμπορικών δραστηριοτήτων εκτός <- Άσκηση εμπορικών δραστηριοτήτων εκτός καταστήματος και άλλες διατάξεις.
# Title:η. καλλιώρας, γ. παπακωνσταντίνου <- Διαχείριση, έλεγχος  και  εφαρμογή αναπτυξιακών παρεμβάσεων για την προγραμματική περίοδο 2007-2013.
# ΕΙΣΗΓΗΤΕΣ: Η. Καλλιώρας, Γ. Παπακωνσταντίνου
# Title:ρυθμίσεις θεμάτων μεταφορών, τηλεπικοινωνιών <- Ρυθμίσεις θεμάτων Μεταφορών, Τηλεπικοινωνιών και Δημοσίων Έργων και άλλες διατάξεις.
# Title:οργάνωση της νομικής μορφής <- Οργάνωση της νομικής μορφής των θρησκευτικών κοινοτήτων και των ενώσεών τους στην Ελλάδα και άλλες διατάξεις αρμοδιότητας Γενικής Γραμματείας Θρησκευμάτων και λοιπές διατάξεις.
# Title:ενσωμάτωση στην ελληνική νομοθεσία <- Ενσωμάτωση στην ελληνική νομοθεσία της Οδηγίας (ΕΕ) 2019/2235 - Κύρωση Πρόσθετης Πράξης στο Νέο Συνυποσχετικό μεταξύ του Ελληνικού Δημοσίου και της Ναυτιλιακής Κοινότητας και φορολογικές ρυθμίσεις για τη ναυτιλία - Επείγουσες φορολογικές και τελωνειακές ρυθμίσεις - Θεσμικό πλαίσιο λειτουργίας της Κεντρικής Μονάδας Κρατικών Ενισχύσεων και του Δικτύου Κρατικών Ενισχύσεων - Μισθολογικές ρυθμίσεις και άλλες διατάξεις οικονομικού και αναπτυξιακού χαρακτήρα.
# Title:κατεπείγουσες ρυθμίσεις αρμοδιότητας των <- Κατεπείγουσες ρυθμίσεις αρμοδιότητας των Υπουργείων Υγείας, Εσωτερικών, Εργασίας και Κοινωνικών
# Υποθέσεων και άλλες διατάξεις
# Title:α. καραμάριος, θ. τζάκρη <- Ενίσχυση του θεσμικού πλαισίου διασφάλισης του απορρήτου της τηλεφωνικής επικοινωνίας και άλλες διατάξεις
# ΕΙΣΗΓΗΤΕΣ: Α. Καραμάριος, Θ. Τζάκρη
# Title:γ. καρασμάνης, φ. χατζημιχάλης <- Εισαγωγή στην Ελληνική Αγορά των Βιοκαυσίμων και των άλλων Ανανεώσιμων Καυσίμων.
# ΕΙΣΗΓΗΤΕΣ: Γ. Καρασμάνης, Φ. Χατζημιχάλης
# Title:απλούστευση της αδειοδότησης για <- Απλούστευση της αδειοδότησης για την άσκηση οικονομικής δραστηριότητας και άλλες
# διατάξεις
# Title:καταπολέμηση της σεξουαλικής κακοποίησης <- Καταπολέμηση της σεξουαλικής κακοποίησης και εκμετάλλευσης παιδιών και της
# παιδικής πορνογραφίας και άλλες διατάξεις.
# Title:γ. κοντογιάννης, α. κατσιφάρας <- Ανάπτυξη ιαματικού τουρισμού και λοιπές διατάξεις.
# ΕΙΣΗΓΗΤΕΣ: Γ. Κοντογιάννης, Α. Κατσιφάρας
# Title:διοικητικές απλουστεύσεις – καταργήσεις, <- Διοικητικές Απλουστεύσεις – Καταργήσεις, Συγχωνεύσεις Νομικών Προσώπων και
# Υπηρεσιών του Δημοσίου Τομέα – Τροποποίηση Διατάξεων του π.δ. 318/1992 (Α΄ 161)
# και λοιπές ρυθμίσεις.
# Title:ρύθμιση θεμάτων της αδμηε <- Ρύθμιση θεμάτων της ΑΔΜΗΕ Α.Ε. και άλλες διατάξεις.
# Title:έρευνα, τεχνολογική ανάπτυξη και <- Έρευνα, Τεχνολογική Ανάπτυξη και Καινοτομία και άλλες διατάξεις.
# Title:π.μελάς, λ. γρηγοράκος <- Οργάνωση και λειτουργία των υπηρεσιών Δημόσιας Υγείας και λοιπές διατάξεις.
#  ΕΙΣΗΓΗΤΕΣ: Π.Μελάς, Λ. Γρηγοράκος
# Title:άδεια εγκατάστασης και λειτουργίας <- Άδεια εγκατάστασης και λειτουργίας χώρου παραστάσεων − Άδεια παράστασης και
# άλλες διατάξεις.
# Title:τουριστικά πλοία και άλλες <- Τουριστικά πλοία και άλλες διατάξεις.
#
# Title:κύρωση της σύμβασης μεταξύ <- Κύρωση της Σύμβασης μεταξύ της Ελληνικής Δημοκρατίας και της Γαλλικής Δημοκρατίας για την εξάλειψη της
# διπλής φορολογίας αναφορικά με φόρους εισοδήματος και την πρόληψη της φοροδιαφυγής και της
# φοροαποφυγής.
# Title:αντιμετώπιση της αυθαίρετης δόμησης <- Αντιμετώπιση της Αυθαίρετης Δόμησης − Περιβαλλοντικό Ισοζύγιο και άλλες διατάξεις

# %% [markdown]
# Do actual Look up of Final Legislations

# %%
import logging



logging.basicConfig(
    filename="final_legislations.log",
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)


SEARCH_URL = "https://www.hellenicparliament.gr/Nomothetiko-Ergo/Anazitisi-Nomothetikou-Ergou"
DOMAIN = "https://www.hellenicparliament.gr"
PDF_PATH ="pdf_files"


with Session(engine) as sess:
    legObjs= sess.execute(
        select(Legislation).where(and_(
            Legislation.id<=880, Legislation.final_legislation_id.is_(None)
        ))
    ).scalars()
    for legObj in legObjs:
        if legObj.final_legislation_id is not None:
            logging.info(f"Legislation Object {LegObj} was already processed with related Legislation id {legObj.final_legislation_id}")
            continue

        title = legObj.title
        title_to_search = pre_process_title_fn(title)
        
        payload = {'criteria':title_to_search}
        r = requests.get(SEARCH_URL,params=payload)

        logging.info(f"Trying url {r.url} for object {legObj.id}, {legObj.title}")

        if r.status_code!=200:
            logging.info(f"Url {r.url} did not respond with 200. Legislation id=={legObj.id}, {legObj.title}")
            continue

        in_search_soup = BeautifulSoup(r.content, features="html.parser")
        if len(in_search_soup.select('tr td a'))>1:
            logging.info(f"Multiple results returned for {legObj.id} with count={len(in_search_soup.select('tr td a'))}, url{r.url}")
        
        if len(in_search_soup.select('tr td a'))==0:
            logging.info(f"Did not find legislation for legObj with id={legObj.id}")
            continue

        legislation_link = in_search_soup.select_one('tr td a').get('href')
        r2 = requests.get(DOMAIN+legislation_link)

        legislation_soup = BeautifulSoup(r2.content, features="html.parser")

        if legislation_soup.find(string="Αριθμός Φεκ") is None: # not a Legislation
            continue

        data={}

        title = legislation_soup.find(string='Τίτλος').next_element.find('dd').string
        data["title"] = title

        legislation_type = legislation_soup.find(string='Τύπος').next_element.find('dd').string if legislation_soup.find(string='Τύπος') is not None else None
        data["legislation_type"] = legislation_type

        ministry = legislation_soup.find(string="Υπουργείο").next_element.find('dd').string if legislation_soup.find(string='Υπουργείο') is not None else None
        data["ministry"] = ministry

        fek_number = legislation_soup.find(string="Αριθμός Φεκ").next_element.find('dd').string if legislation_soup.find(string='Αριθμός Φεκ') is not None else None
        data["fek_number"] = fek_number

        date_posted = legislation_soup.find(string="Ημ. Ψήφισης").next_element.find('dd').string if legislation_soup.find(string='Ημ. Ψήφισης') is not None else None
        date_posted = datetime.strptime(date_posted,"%d/%m/%Y") if date_posted is not None else None
        data["date_posted"] = date_posted

        legislation_url = legislation_soup.find(string="Ψηφισθέν Νομοσχέδιο").next_element.find('a').get('href')
        data["legislation_pdf_url"] = legislation_url

        data["scrap_url"] = r2.url

        newLegObj = Legislation(**data)
        sess.add(newLegObj)
        sess.commit()  # Get Primary Key
        print(newLegObj)
        legObj.final_legislation_id = newLegObj.id
        sess.commit()

        with open(os.path.join(PDF_PATH,f"{str(newLegObj.id)}.pdf"),'wb') as pdffile:
            response = requests.get(legislation_url) 
            pdffile.write(response.content)

  
    
logging.shutdown()
# Out:
# Legislation(id=1178, title=Διατάξεις για τη θωράκιση του θεσμικού πλαισίου του αθλητισμού και τον εξορθολογισμό της αθλητικής νομοθεσίας, ministry=Πολιτισμού και Αθλητισμού, date_posted=2023-02-21)
# Legislation(id=1179, title=Κανόνες Τεκμηρίωσης Ενδοομιλικών Συναλλαγών, Κανόνες Υποκεφαλαιοδότησης Επιχειρήσεων, Διαδικασία Ταχείας Αδειοδότησης και άλλες διατάξεις.
# ΕΙΣΗΓΗΤΕΣ: Π. Μπετζάλη, Κ. Σπηλιόπουλος, ministry=Οικονομίας και Οικονομικών, date_posted=2009-07-14)
# Legislation(id=1180, title=Σύσταση νομικού προσώπου ιδιωτικού δικαίου με την επωνυμία «Ογκολογικό Κέντρο Παίδων ''Μαριάννα Β.
# Βαρδινογιάννη - ΕΛΠΙΔΑ''», εκσυγχρονισμός του δικαίου για τη δωρεά και μεταμόσχευση οργάνων, ρυθμίσεις για
# την αντιμετώπιση της πανδημίας του κορωνοϊού COVID-19 και την προστασία της δημοσίας υγείας και άλλες
# επείγουσες ρυθμίσεις, ministry=Υγείας, date_posted=2023-03-15)
# Legislation(id=1181, title=Διαχείριση, έλεγχος  και  εφαρμογή αναπτυξιακών παρεμβάσεων για την προγραμματική περίοδο 2007-2013.
# ΕΙΣΗΓΗΤΕΣ: Η. Καλλιώρας, Γ. Παπακωνσταντίνου, ministry=Οικονομίας και Οικονομικών, date_posted=2007-11-21)
# Legislation(id=1182, title=Οργάνωση και λειτουργία των υπηρεσιών Δημόσιας Υγείας και λοιπές διατάξεις.
#  ΕΙΣΗΓΗΤΕΣ: Π.Μελάς, Λ. Γρηγοράκος, ministry=Υγείας και Κοινωνικής Αλληλεγγύης, date_posted=2005-06-27)
# Legislation(id=1183, title=Για την Προστασία της Εργασίας - Σύσταση Ανεξάρτητης Αρχής «Επιθεώρηση Εργασίας» - Κύρωση της Σύμβασης 190 της Διεθνούς Οργάνωσης Εργασίας για την εξάλειψη της βίας και παρενόχλησης στον κόσμο της εργασίας -
# Κύρωση της Σύμβασης 187 της Διεθνούς Οργάνωσης Εργασίας για τo Πλαίσιο Προώθησης της Ασφάλειας και της Υγείας στην Εργασία - Ενσωμάτωση της Οδηγίας (ΕΕ) 2019/1158 του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου
# της 20ής Ιουνίου 2019 για την ισορροπία μεταξύ της επαγγελματικής και της ιδιωτικής ζωής, άλλες διατάξεις του Υπουργείου Εργασίας και Κοινωνικών Υποθέσεων και λοιπές επείγουσες ρυθμίσεις., ministry=Εργασίας και Κοινωνικών Υποθέσεων, date_posted=2021-06-16)
# Legislation(id=1184, title=Ρυθμίσεις για τη διασφάλιση της πρόσβασης σε ποιοτικές υπηρεσίες υγείας - Ίδρυση και καταστατικό του
# Οργανισμού Διασφάλισης της Ποιότητας στην Υγεία Α.Ε. (Ο.ΔΙ.Π.Υ. Α.Ε.), άλλες επείγουσες διατάξεις αρμοδιότητας
# του Υπουργείου Υγείας και άλλες διατάξεις., ministry=Υγείας, date_posted=2020-07-30)
# Legislation(id=1185, title=I) Κύρωση και προσαρμογή της ελληνικής νομοθεσίας στη Σύμβαση της Βαρσοβίας της 16ης Μαΐου 2005 του
# Συμβουλίου της Ευρώπης για τη νομιμοποίηση, ανίχνευση, κατάσχεση και δήμευση εσόδων από εγκληματικές
# δραστηριότητες και
# για τη χρηματοδότηση της τρομοκρατίας, ενσωμάτωση της Α-Π 2003/577/ΔΕΥ, της Α-Π 2005/212/ΔΕΥ, της
# Α-Π 2006/783/ΔΕΥ, όπως τροποποιήθηκε με την Α-Π 2009/299/ΔΕΥ, και της Οδηγίας 2014/42/ΕΕ, II)
# Προϋποθέσεις
# τοποθέτησης ανηλίκων σε ίδρυμα ή ανάδοχη οικογένεια από και προς κράτη - μέλη της Ευρωπαϊκής Ένωσης
# βάσει του άρθρου 56 του Κανονισμού (ΕΚ) αριθμ. 2201/2003 του Συμβουλίου της 27ης Νοεμβρίου 2003, για
# τη διεθνή
# δικαιοδοσία και την αναγνώριση και εκτέλεση αποφάσεων σε γαμικές διαφορές και διαφορές γονικής μέριμνας, ο
# οποίος καταργεί τον Κανονισμό (ΕΚ) 1347/2000, III) Ενσωμάτωση της Οδηγίας 2013/48/ΕΕ του Ευρωπαϊκού
# Κοινοβουλίου
# και του Συμβουλίου της 22ας Οκτωβρίου 2013, σχετικά με το δικαίωμα πρόσβασης σε δικηγόρο στο πλαίσιο
# ποινικής διαδικασίας και διαδικασίας εκτέλεσης του ευρωπαϊκού εντάλματος σύλληψης, καθώς και σχετικά με το
# δικαίωμα
# ενημέρωσης τρίτου προσώπου σε περίπτωση στέρησης της ελευθερίας του και με το δικαίωμα επικοινωνίας με
# τρίτα πρόσωπα και με προξενικές αρχές κατά τη διάρκεια στέρησης της ελευθερίας, IV) Ενσωμάτωση της
# Οδηγίας 2012/29/ΕΕ
# για τη θέσπιση ελάχιστων προτύπων σχετικά με τα δικαιώματα, την υποστήριξη και την προστασία θυμάτων της
# εγκληματικότητας και για την αντικατάσταση της Απόφασης - Πλαίσιο 2001/220/ΔΕΥ του Συμβουλίου και
# λοιπές διατάξεις., ministry=Δικαιοσύνης, Διαφάνειας και Ανθρωπίνων Δικαιωμάτων, date_posted=2017-06-21)
# Legislation(id=1186, title=Ρυθμίσεις για την ελληνόγλωσση εκπαίδευση, τη διαπολιτισμική εκπαίδευση και άλλες διατάξεις., ministry=Παιδείας, Έρευνας και Θρησκευμάτων, date_posted=2016-08-31)
# Legislation(id=1187, title=Οργάνωση και λειτουργία της ανώτατης εκπαίδευσης, ρυθμίσεις για την έρευνα και άλλες διατάξεις., ministry=Παιδείας, Έρευνας και Θρησκευμάτων, date_posted=2017-08-02)
# Legislation(id=1188, title=Ρυθμίσεις για τη λήψη άμεσων μέτρων για την αντιμετώπιση της ανθρωπιστικής κρίσης, την οργάνωση της Κυβέρνησης και των Κυβερνητικών οργάνων και λοιπές διατάξεις., ministry=Εργασίας και Κοινωνικής Αλληλεγγύης, date_posted=2015-03-18)
# Legislation(id=1189, title=Συνταξιοδοτικές ρυθμίσεις, ενσωμάτωση στο Ελληνικό Δίκαιο της Οδηγίας 2012/27/ΕΕ του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου της 25ης Οκτωβρίου 2012 «Για την ενεργειακή απόδοση, την τροποποίηση των Οδηγιών 2009/125/ΕΚ και 2010/30/ΕΕ και την κατάργηση των Οδηγιών 2004/8/ΕΚ και 2006/32/ΕΚ», όπως τροποποιήθηκε από την Οδηγία 2013/12/ΕΕ του Συμβουλίου της 13ης Μαΐου 2013 «Για την προσαρμογή της Οδηγίας 2012/27/ΕΕ του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου για την ενεργειακή απόδοση, λόγω της προσχώρησης της Δημοκρατίας της Κροατίας» και άλλες διατάξεις., ministry=Περιβάλλοντος και Ενέργειας, date_posted=2015-11-05)
# Legislation(id=1190, title=Ανοικτή διάθεση και περαιτέρω χρήση εγγράφων, πληροφοριών και δεδομένων του δημόσιου τομέα, τροποποίηση του ν. 3448/2006 (Α΄ 57), προσαρμογή της εθνικής νομοθεσίας στις διατάξεις της Οδηγίας 2013/37/ΕΕ του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου, περαιτέρω ενίσχυση της διαφάνειας, ρυθμίσεις θεμάτων Εισαγωγικού Διαγωνισμού Ε.Σ.Δ.Δ.Α. και άλλες διατάξεις
# , ministry=None, date_posted=2014-10-24)
# Legislation(id=1191, title=Ρυθμίσεις Υπουργείου Διοικητικής Μεταρρύθμισης και Ηλεκτρονικής Διακυβέρνησης, ministry=Διοικητικής Μεταρρύθμισης και Ηλεκτρονικής Διακυβέρνησης, date_posted=2013-11-13)
# Legislation(id=1192, title=Αναδιάρθρωση της Δευτεροβάθμιας Εκπαίδευσης και λοιπές διατάξεις, ministry=Παιδείας  Και  Θρησκευμάτων, date_posted=2013-09-10)
περιβάλλοντος, Ενέργειας και Κλιματικής Αλλαγής
# , ministry=Περιβάλλοντος, Ενέργειας και Κλιματικής Αλλαγής, date_posted=2013-05-28)
# Legislation(id=1203, title=Διοικητικά μέτρα, διαδικασίες και κυρώσεις στην εφαρμογή της ενωσιακής και εθνικής
# νομοθεσίας στους τομείς των τροφίμων, των ζωοτροφών και της υγείας
# και προστασίας των ζώων και άλλες διατάξεις αρμοδιότητας του Υπουργείου Αγροτικής
# Ανάπτυξης και Τροφίμων., ministry=Αγροτικής Ανάπτυξης και Τροφίμων, date_posted=2014-01-30)
# Legislation(id=1204, title=Ρυθμίσεις για την τροποποίηση και τη βελτίωση συνταξιοδοτικών, δημοσιονομικών, διοικητικών και λοιπών διατάξεων του Υπουργείου Οικονομικών, ministry=Οικονομικών, date_posted=2013-04-28)
# Legislation(id=1205, title=Υπηρεσία Εποπτείας Αγοράς και άλλες διατάξεις ΕΙΣΗΓΗΤΕΣ: Α. Καραμάριος και Β. Κεγκέρογλου, ministry=Αναπτυξης, date_posted=2008-12-02)
# Legislation(id=1206, title=Ανασυγκρότηση του Υπουργείου Ναυτιλίας και Αιγαίου και άλλες διατάξεις, ministry=Ναυτιλίας και Αιγαίου, date_posted=2013-04-23)
# Legislation(id=1207, title=Ρυθμίσεις θεμάτων Ανανεώσιμων Πηγών Ενέργειας και άλλες διατάξεις.
#
# , ministry=Περιβάλλοντος, Ενέργειας και Κλιματικής Αλλαγής, date_posted=2013-10-24)
# Legislation(id=1208, title=Κατάργηση και συγχώνευση νομικών προσώπων του Δημοσίου και του ευρύτερου δημόσιου τομέα − Σύσταση Γενικής Γραμματείας για το συντονισμό του κυβερνητικού έργου και άλλες διατάξεις, ministry=Διοικητικής Μεταρρύθμισης και Ηλεκτρονικής Διακυβέρνησης, date_posted=2013-01-09)
# Legislation(id=1209, title=Ενεργειακή Απόδοση Κτιρίων – Εναρμόνιση με την Οδηγία 2010/31/ΕΕ του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου και λοιπές διατάξεις, ministry=Περιβάλλοντος, Ενέργειας και Κλιματικής Αλλαγής, date_posted=2013-02-05)
# Legislation(id=1210, title=Ενσωμάτωση στην ελληνική νομοθεσία της Οδηγίας (ΕΕ) 2019/2235 - Κύρωση Πρόσθετης Πράξης στο Νέο Συνυποσχετικό μεταξύ του Ελληνικού Δημοσίου και της Ναυτιλιακής Κοινότητας και φορολογικές ρυθμίσεις για τη ναυτιλία - Επείγουσες φορολογικές και τελωνειακές ρυθμίσεις - Θεσμικό πλαίσιο λειτουργίας της Κεντρικής Μονάδας Κρατικών Ενισχύσεων και του Δικτύου Κρατικών Ενισχύσεων - Μισθολογικές ρυθμίσεις και άλλες διατάξεις οικονομικού και αναπτυξιακού χαρακτήρα., ministry=Οικονομικών, date_posted=2022-12-06)
# Legislation(id=1211, title=Ενσωμάτωση στην ελληνική νομοθεσία της Οδηγίας 2014/50/ΕΕ του Ευρωπαϊκού Κοινοβουλίου και του
# Συμβουλίου της 16ης Απριλίου 2014, σχετικά με τις ελάχιστες προϋποθέσεις για την προαγωγή της κινητικότητας
# των εργαζομένων μεταξύ των κρατών-μελών, με τη βελτίωση της απόκτησης και της διατήρησης δικαιωμάτων
# συμπληρωματικής συνταξιοδότησης» (L 128/1 της 30.4.2014) και άλλες διατάξεις., ministry=Εργασίας, Κοινωνικής Ασφάλισης και Κοινωνικής Αλληλεγγύης, date_posted=2018-11-08)
# Legislation(id=1212, title=Κύρωση Σύμβασης Παραχώρησης του Έργου της Μελέτης, Κατασκευής, Χρηματοδότησης, Λειτουργίας, Συντήρησης και Εκμετάλλευσης του Αυτοκινητοδρόμου Ελευσίνα - Κόρινθος - Πάτρα - Πύργος - Τσακώνα και άλλες διατάξεις
# , ministry=Περιβάλλοντος, Χωροταξίας και Δημοσίων 'Εργων, date_posted=2007-11-29)
# Legislation(id=1213, title=Ρυθμίσεις για την τοπική ανάπτυξη, την αυτοδιοίκηση και την αποκεντρωμένη διοίκηση Ενσωμάτωση Οδηγίας 2009/50/ΕΚ, ministry=Εσωτερικών, date_posted=2012-04-09)
# Legislation(id=1214, title=Ρυθμίσεις θεμάτων προσωπικού με σύμβαση εργασίας ιδιωτικού δικαίου αορίστου χρόνου και άλλες διατάξεις οργάνωσης και λειτουργίας της Δημόσιας Διοίκησης.
# ΕΙΣΗΓΗΤΕΣ: Σ. Κεδίκογλου, Π. Ρήγας, ministry=Εσωτερικών, date_posted=2009-09-02)
# Legislation(id=1215, title=Μεταβολές στη φορολογία εισοδήματος, απλουστεύσεις στον Κώδικα Βιβλίων και Στοιχείων και άλλες διατάξεις.
# ΕΙΣΗΓΗΤΕΣ: Α. Κωστόπουλος, Α. Μακρυπίδης, ministry=None, date_posted=2006-12-20)
# Legislation(id=1216, title=Ενιαίο ρυθμιστικό πλαίσιο για την οργάνωση και λειτουργία του Ελληνικού Γεωργικού Οργανισμού - ΔΗΜΗΤΡΑ, σύσταση και λειτουργία φορέα διαχείρισης Παραδοσιακού Ελαιώνα Άμφισσας και άλλες διατάξεις για την ενίσχυση της αγροτικής ανάπτυξης, ministry=Αγροτικής Ανάπτυξης και Τροφίμων, date_posted=2023-03-22)
# Legislation(id=1217, title=Νέος Οικοδομικός Κανονισμός, ministry=Περιβάλλοντος, Ενέργειας και Κλιματικής Αλλαγής, date_posted=2012-04-03)
# Legislation(id=1218, title=Διατήρηση ενός ελάχιστου επιπέδου αποθεμάτων αργού πετρελαίου ή/και προϊόντων πετρελαίου και άλλες διατάξεις (Εναρμόνιση του εθνικού δικαίου προς την Οδηγία 2009/119/ΕΚ)., ministry=Περιβάλλοντος, Ενέργειας και Κλιματικής Αλλαγής, date_posted=2013-02-12)
# Legislation(id=1219, title=Αναδιοργάνωση της δημοτικής αστυνομίας και ρυθμίσεις λοιπών θεμάτων αρμοδιότητας Υπουργείου Εσωτερικών.
# ΕΙΣΗΓΗΤΕΣ: Σ. Κεδίκογλου, Γ. Ντόλιος
# , ministry=Εσωτερικών, date_posted=2008-12-15)
# Legislation(id=1220, title=Διασυνοριακές Συγχωνεύσεις Κεφαλαιουχικών Εταιρειών και άλλες διατάξεις
# ΕΙΣΗΓΗΤΕΣ: Α. Καρούζας, Δ. Τσιρώνης, ministry=Αναπτυξης, date_posted=2009-07-09)
# Legislation(id=1221, title=Ρυθμίσεις για την κτηνοτροφία και τις κτηνοτροφικές εγκαταστάσεις και άλλες διατάξεις., ministry=Αγροτικής Ανάπτυξης και Τροφίμων, date_posted=2012-03-08)
# Legislation(id=1222, title=Εναρμόνιση της ελληνικής νομοθεσίας με την εκτελεστική Οδηγία (ΕΕ) 2019/69 της επιτροπής της 16ης Ιανουαρίου 2019 για τη θέσπιση τεχνικών προδιαγραφών για τα όπλα συναγερμού και σηματοδοσίας δυνάμει της Οδηγίας
# 91/477/ΕΟΚ του Συμβουλίου της 18ης Ιουνίου 1991 σχετικά με τον έλεγχο της απόκτησης και της κατοχής όπλων, όπως κωδικοποιήθηκε με την Οδηγία 2021/555 του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου της 24ης
# Μαρτίου 2021 σχετικά με τον έλεγχο της απόκτησης και της κατοχής όπλων (L 115)., ministry=Προστασίας του Πολίτη, date_posted=2022-04-18)
# Legislation(id=1223, title=Προσαρμογή στις διατάξεις της οδηγίας 2009/18/ΕΚ του Ευρωπαϊκού Κοινοβουλίου και
# του Συμβουλίου της 23ης Απριλίου 2009 για τον καθορισμό των θεμελιωδών αρχών
# που διέπουν τη διερεύνηση των ατυχημάτων στον τομέα των θαλάσσιων μεταφορών και
# για την τροποποίηση της οδηγίας 1999/35/ΕΚ του Συμβουλίου και της οδηγίας
# 2002/59/ΕΚ του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου. Ενσωμάτωση
# ρυθμίσεων, μέτρα εφαρμογής και άλλες διατάξεις., ministry=Προστασίας του Πολίτη, date_posted=2011-12-15)
# Legislation(id=1224, title=Προσαρμογή της ελληνικής νομοθεσίας προς την Οδηγία (ΕΕ) 2019/2161 του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου της 27ης Νοεμβρίου 2019 για την τροποποίηση της Οδηγίας 93/13/
# ΕΟΚ του Συμβουλίου και των Οδηγιών 98/6/ΕΚ, 2005/29/ΕΚ και 2011/83/ΕΕ του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου όσον αφορά στην καλύτερη επιβολή και τον εκσυγχρονισμό των
# κανόνων της Ένωσης για την προστασία των καταναλωτών και άλλες διατάξεις., ministry=Ανάπτυξης και Επενδύσεων, date_posted=2022-05-18)
# Legislation(id=1225, title=Κύρωση του Μνημονίου Συννενόησης και της Συμφωνίας μεταξύ της Κυβέρνησης της Ελληνικής Δημοκρατίας και της Κυβέρνησης των Ηνωμένων Πολιτειών της Αμερικής για τη βελτίωση της διεθνούς
# φορολογικής συμμόρφωσης και την εφαρμογή του νόμου περί Φορολογικής Συμμόρφωσης Λογαριασμών της Αλλοδαπής (FATCA), καθώς και της Συμφωνίας Αρμόδιων Αρχών και διατάξεις εφαρμογής., ministry=Οικονομικών, date_posted=2017-10-26)
# Legislation(id=1226, title=Ίδρυση, οργάνωση και λειτουργία αθλητικών επαγγελματικών ενώσεων και άλλες διατάξεις, ministry=None, date_posted=2006-07-11)
# Legislation(id=1227, title=Διεύρυνση της άμεσης και συμμετοχικής δημοκρατίας με τη διενέργεια δημοψηφίσματος, ministry=Εσωτερικών, date_posted=2011-10-05)
# Legislation(id=1228, title=Κύρωση της από 31 Οκτωβρίου 2012 Πράξης Νομοθετικού Περιεχομένου «Τροποποίηση
# της παρ. 16 του άρθρου 49 του ν. 4030/2011 «Νέος τρόπος έκδοσης αδειών δόμησης,
# ελέγχου κατασκευών και λοιπές διατάξεις (Α΄ 249)» και λοιπές διατάξεις του
# Υπουργείου Περιβάλλοντος, Ενέργειας και Κλιματικής Αλλαγής., ministry=Περιβάλλοντος, Ενέργειας και Κλιματικής Αλλαγής, date_posted=2013-01-24)
# Legislation(id=1229, title=Εκδίκαση πράξεων διαφθοράς πολιτικών και κρατικών αξιωματούχων, υποθέσεων
# μεγάλου κοινωνικού ενδιαφέροντος και μείζονος δημοσίου συμφέροντος και άλλες διατάξεις, ministry=Δικαιοσύνης, Διαφάνειας και Ανθρωπίνων Δικαιωμάτων, date_posted=2011-09-28)
# Legislation(id=1230, title=Τροποποίηση διατάξεων του ν. 2168/1993 «Ρύθμιση θεμάτων που αφορούν όπλα,
# πυρομαχικά, εκρηκτικές ύλες, εκρηκτικούς μηχανισμούς και άλλες διατάξεις» (Α΄147)
# και προσαρμογή στις διατάξεις της Οδηγίας 2009/43/ΕΚ του Ευρωπαϊκού Κοινοβουλίου
# και του Συμβουλίου της 6ης Μαϊου 2009 «για την απλούστευση των όρων και
# προϋποθέσεων για τις μεταφορές προϊόντων συνδεόμενων με τον τομέα της άμυνας
# εντός της Κοινότητας (ΕΕ L 146 της 10.6.2009), όπως τροποποιήθηκε με την Οδηγία
# 2010/80/ΕΕ όσον αφορά τον κατάλογο προϊόντων συνδεομένων με τον τομέα της
# άμυνας (ΕΕ C 69 της 18.3.2010)., ministry=Ανάπτυξης Ανταγωνιστικότητας και Ναυτιλίας, date_posted=2011-11-07)
# Legislation(id=1231, title=Ζώνη Καινοτομίας Θεσσαλονίκης και άλλες διατάξεις.
# ΕΙΣΗΓΗΤΕΣ: Σ. Καλαφάτης, Ι. Μανιάτης, ministry=Αναπτυξης, date_posted=2006-09-12)
# Legislation(id=1232, title=Σύσταση νομικού προσώπου ιδιωτικού δικαίου με την επωνυμία «Ογκολογικό Κέντρο Παίδων ''Μαριάννα Β.
# Βαρδινογιάννη - ΕΛΠΙΔΑ''», εκσυγχρονισμός του δικαίου για τη δωρεά και μεταμόσχευση οργάνων, ρυθμίσεις για
# την αντιμετώπιση της πανδημίας του κορωνοϊού COVID-19 και την προστασία της δημοσίας υγείας και άλλες
# επείγουσες ρυθμίσεις, ministry=Υγείας, date_posted=2023-03-15)
# Legislation(id=1233, title=Αναμόρφωση του θεσμικού πλαισίου λειτουργίας του Ταμείου Χρηματοπιστωτικής Σταθερότητας και του
# Συνεγγυητικού Κεφαλαίου Εξασφάλισης Επενδυτικών Υπηρεσιών, εκσυγχρονισμός Οργανισμού Διαχείρισης
# Δημοσίου Χρέους και άλλες επείγουσες διατάξεις., ministry=Οικονομικών, date_posted=2022-06-15)
# Legislation(id=1234, title=Θεσμικό πλαίσιο για τους αγροτικούς συνεταιρισμούς, τις συλλογικές οργανώσεις και
# την
# επιχειρηματικότητα του αγροτικού κόσμου – Οργάνωση της εποπτείας του Κράτους., ministry=Αγροτικής Ανάπτυξης και Τροφίμων, date_posted=2011-09-13)
# Legislation(id=1235, title=«Κύρωση της από 8 Ιανουαρίου 2011 Πράξης Νομοθετικού Περιεχομένου «Αναστολή προθεσμιών και εργασιών του Διοικητικού Πρωτοδικείου και του Διοικητικού Εφετείου Αθηνών» και άλλες διατάξεις» , ministry=Δικαιοσύνης, Διαφάνειας και Ανθρωπίνων Δικαιωμάτων, date_posted=2011-03-23)
# Legislation(id=1236, title=Ενιαία Αρχή Δημοσίων Συμβάσεων και άλλες διατάξεις του Υπουργείου Δικαιοσύνης, ministry=Αντιπρόεδρος της Κυβέρνησης , date_posted=2022-03-15)
# Legislation(id=1237, title=Αρχή της επαγγελματικής ελευθερίας. Κατάργηση αδικαιολόγητων περιορισμών στην πρόσβαση και άσκηση επαγγελμάτων, ministry=Οικονομικών, date_posted=2011-02-22)
# Legislation(id=1238, title=Πρόσβαση στην τριτοβάθμια εκπαίδευση των κατόχων απολυτηρίου Επαγγελματικού Λυκείου και άλλες διατάξεις.
# ΕΙΣΗΓΗΤΕΣ: Α. Ράγιου - Μεντζελοπούλου,  Δ. Βαρβαρίγος, ministry=Εθνικής Παιδείας και Θρησκευμάτων, date_posted=2009-02-10)
# Legislation(id=1239, title=Σύσταση αρχής καταπολέμησης της νομιμοποίησης εσόδων από εγκληματικές
# δραστηριότητες και της χρηματοδότησης της τρομοκρατίας, και ελέγχου των δηλώσεων περιουσιακής κατάστασης, ministry=Δικαιοσύνης, Διαφάνειας και Ανθρωπίνων Δικαιωμάτων, date_posted=2011-03-01)
# Legislation(id=1240, title=Διαρθρωτικές αλλαγές στο σύστημα υγείας και άλλες διατάξεις, ministry=Υγείας και Κοινωνικής Αλληλεγγύης, date_posted=2011-02-15)
# Legislation(id=1241, title=Αναθεώρηση Διατάξεων του v. 703/1977 περί Ανταγωνισμού και άλλες διατάξεις
# ΕΙΣΗΓΗΤΕΣ: Μανούσος Βολουδάκης και Απόστολος Κατσιφάρας, ministry=Αναπτυξης, date_posted=2009-07-23)
# Legislation(id=1242, title=Ενίσχυση Ιδιωτικών Επενδύσεων για την Οικονομική Ανάπτυξη, την Επιχειρηματικότητα και την
# Περιφερειακή Συνοχή, ministry=Οικονομίας, Ανταγωνιστικότητας και Ναυτιλίας, date_posted=2011-01-25)
# Legislation(id=1243, title=Σύσταση Αρχηγείου Λιμενικού Σώματος – Ελληνικής Ακτοφυλακής και άλλες διατάξεις, ministry=Προστασίας του Πολίτη, date_posted=2011-02-24)
# Legislation(id=1244, title=Περί Ηλεκτρονικών Επικοινωνιών και άλλες διατάξεις
# ΕΙΣΗΓΗΤΕΣ: Ι. Γαρουφαλιάς, Ε. Στρατάκης., ministry=None, date_posted=2006-01-17)
# Legislation(id=1245, title=Εθνική στρατηγική για την προστασία και διαχείριση του θαλάσσιου περιβάλλοντος -
# Εναρμόνιση με την οδηγία 2008/56/ΕΚ του Ευρωπαϊκού Κοινοβουλίου και του
# Συμβουλίου της 17ης Ιουνίου 2008 και άλλες διατάξεις, ministry=Περιβάλλοντος, Ενέργειας και Κλιματικής Αλλαγής, date_posted=2011-06-14)
# Legislation(id=1246, title=Σύσταση Γραφείου Αντιμετώπισης Περιστατικών Αυθαιρεσίας στο Υπουργείο Προστασίας του Πολίτη και άλλες διατάξεις, ministry=Προστασίας του Πολίτη, date_posted=2011-03-15)
# Legislation(id=1247, title=Σύσταση Εθνικού Ταμείου Επιχειρηματικότητας και Ανάπτυξης , ministry=Οικονομίας, Ανταγωνιστικότητας και Ναυτιλίας, date_posted=2011-02-08)
# Legislation(id=1248, title=Ίδρυση Υπηρεσίας Ασύλου και Υπηρεσίας Πρώτης Υποδοχής, προσαρμογή της ελληνικής νομοθεσίας προς τις διατάξεις της Οδηγίας 2008/115/ΕΚ «σχετικά με τους κοινούς κανόνες και διαδικασίες στα κράτη μέλη για την επιστροφή των παρανόμως διαμενόντων υπηκόων τρίτων χωρών» και λοιπές διατάξεις, ministry=Προστασίας του Πολίτη, date_posted=2011-01-18)
# Legislation(id=1249, title=Ενίσχυση και ανάπτυξη της κινηματογραφικής τέχνης και άλλες διατάξεις., ministry=Πολιτισμού και Τουρισμού, date_posted=2010-12-21)
# Legislation(id=1250, title=Προσαρμογή των διατάξεων του εσωτερικού δικαίου προς τις διατάξεις του
# καταστατικού του Διεθνούς Ποινικού Δικαστηρίου που κυρώθηκε με τον ν. 3003/2002
# (ΦΕΚ 75 Α'), ministry=Δικαιοσύνης, Διαφάνειας και Ανθρωπίνων Δικαιωμάτων, date_posted=2011-03-29)
# Legislation(id=1251, title=Εφαρμογή της αρχής των ίσων ευκαιριών και της ίσης μεταχείρισης ανδρών και γυναικών σε θέματα εργασίας και απασχόλησης – Εναρμόνιση της κείμενης νομοθεσίας με την Οδηγία 2006/54/ΕΚ του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου, της 5ης Ιουλίου 2006 και άλλες συναφείς διατάξεις, ministry=Εργασίας και Κοινωνικής Ασφάλισης, date_posted=2010-11-30)
# Legislation(id=1252, title=Πιστοποίηση των μηχανοδηγών και άλλες διατάξεις, ministry=Υποδομών, Μεταφορών και Δικτύων, date_posted=2011-02-01)
# Legislation(id=1253, title=Εναρμόνιση της ελληνικής νομοθεσίας με την εκτελεστική Οδηγία (ΕΕ) 2019/69 της επιτροπής της 16ης Ιανουαρίου 2019 για τη θέσπιση τεχνικών προδιαγραφών για τα όπλα συναγερμού και σηματοδοσίας δυνάμει της Οδηγίας
# 91/477/ΕΟΚ του Συμβουλίου της 18ης Ιουνίου 1991 σχετικά με τον έλεγχο της απόκτησης και της κατοχής όπλων, όπως κωδικοποιήθηκε με την Οδηγία 2021/555 του Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου της 24ης
# Μαρτίου 2021 σχετικά με τον έλεγχο της απόκτησης και της κατοχής όπλων (L 115)., ministry=Προστασίας του Πολίτη, date_posted=2022-04-18)
# Legislation(id=1254, title=Εξορθολογισμός διαδικασιών και επιτάχυνση της διοικητικής δίκης και άλλες διατάξεις., ministry=Δικαιοσύνης, Διαφάνειας και Ανθρωπίνων Δικαιωμάτων, date_posted=2010-12-15)
# Legislation(id=1255, title=Αναδιάρθρωση, εξυγίανση και ανάπτυξη του ομίλου ΟΣΕ και της ΤΡΑΙΝΟΣΕ και άλλες διατάξεις για το σιδηροδρομικό τομέα. , ministry=Υποδομών, Μεταφορών και Δικτύων, date_posted=2010-10-26)
# Legislation(id=1256, title=Οργάνωση και λειτουργία των υπηρεσιών Δημόσιας Υγείας και λοιπές διατάξεις.
#  ΕΙΣΗΓΗΤΕΣ: Π.Μελάς, Λ. Γρηγοράκος, ministry=Υγείας και Κοινωνικής Αλληλεγγύης, date_posted=2005-06-27)
# Legislation(id=1257, title=Στην πρόταση «για την τροποποίηση διατάξεων του Κανονισμού της Βουλής (Μέρος Κοινοβουλευτικό και Μέρος Β΄)», ministry=Κανονισμός Βουλής, date_posted=2008-06-25)
# Legislation(id=1258, title=Παραγωγή Ηλεκτρικής Ενέργειας από Ανανεώσιμες Πηγές Ενέργειας και Συμπαραγωγή Ηλεκτρισμού και Θερμότητας Υψηλής Απόδοσης και λοιπές διατάξεις
# ΕΙΣΗΓΗΤΕΣ: Γ. Δεικτάκης, Α. Παπαγεωργίου, ministry=Αναπτυξης, date_posted=2006-06-06)
# Legislation(id=1259, title=Αναδιοργάνωση της Υπηρεσίας Πολιτικής Αεροπορίας και άλλες διατάξεις
#
#
# , ministry=Υποδομών, Μεταφορών και Δικτύων, date_posted=2011-02-08)
# Legislation(id=1260, title=Εκλογικές δαπάνες συνδυασμών και υποψηφίων και έλεγχος αυτών, κατά τις περιφερειακές και
# δημοτικές εκλογές, ministry=Εσωτερικών, Αποκέντρωσης και Ηλεκτρονικής Διακυβέρνησης, date_posted=2010-07-30)
# Legislation(id=1261, title=Τροποποίηση και συμπλήρωση της συνταξιοδοτικής νομοθεσίας του Δημοσίου και άλλες διατάξεις. ΕΙΣΗΓΗΤΕΣ: Δ. Πιπεργιάς, Ν. Αγγελόπουλος, ministry=Οικονομίας και Οικονομικών, date_posted=2002-11-13)
# Legislation(id=1262, title=Εκτέλεση περιηγητικών πλόων από πλοία με σημαία τρίτων χωρών με αφετηρία ελληνικό λιμένα και άλλες διατάξεις, ministry=Οικονομίας, Ανταγωνιστικότητας και Ναυτιλίας, date_posted=2010-08-31)
# Legislation(id=1263, title=Εθνική Υποδομή Γεωχωρικών Πληροφοριών - Εναρμόνιση με την οδηγία 2007/2/ΕΚ του Ευρωπαϊκού  Κοινοβουλίου και του Συμβουλίου της 14ης Μαρτίου 2007 και άλλες διατάξεις. Τροποποίηση του Ν. 1647/1986 «Οργανισμός Κτηματολογίου και Χαρτογραφήσεων Ελλάδας (ΟΚΧΕ) και άλλες σχετικές
# διατάξεις»  (ΦΕΚ 141 Α'), ministry=Περιβάλλοντος, Ενέργειας και Κλιματικής Αλλαγής, date_posted=2010-09-20)
# Legislation(id=1264, title=Επιλογή στελεχών πρωτοβάθμιας και δευτεροβάθμιας εκπαίδευσης, ρύθμιση θεμάτων διοίκησης και εκπαίδευσης και άλλες διατάξεις
# ΕΙΣΗΓΗΤΕΣ: M. Χαλκίδης, Δ. Βαρβαρίγος, ministry=Εθνικής Παιδείας και Θρησκευμάτων, date_posted=2006-06-06)
# Legislation(id=1265, title=Δικαστική προστασία κατά τη σύναψη δημοσίων συμβάσεων - Εναρμόνιση της ελληνικής νομοθεσίας
# με την Οδηγία 89/665/ΕΟΚ του Συμβουλίου της 21ης Ιουνίου 1989 (L 395) και την Οδηγία 92/13/ΕΟΚ
# του Συμβουλίου της 25ης Φεβρουαρίου 1992 (L 76), όπως τροποποιήθηκαν με την Οδηγία 2007/66/ΕΚ
# του Ευρωπαϊκού Κοινοβουλίου και του ΣΥμβουλίου της 11ης Δεκεμβρίου 2007 (L 335), ministry=Δικαιοσύνης, Διαφάνειας και Ανθρωπίνων Δικαιωμάτων, date_posted=2010-09-29)
# Legislation(id=1266, title=Εθνική στρατηγική για την προστασία και διαχείριση του θαλάσσιου περιβάλλοντος -
# Εναρμόνιση με την οδηγία 2008/56/ΕΚ του Ευρωπαϊκού Κοινοβουλίου και του
# Συμβουλίου της 17ης Ιουνίου 2008 και άλλες διατάξεις, ministry=Περιβάλλοντος, Ενέργειας και Κλιματικής Αλλαγής, date_posted=2011-06-14)

# %% [markdown]
# after scraping, compare titles with final and initial legislation
# find legislationId with mutiple counts

# %% [markdown]
# Logging

# %%
import logging

logging.basicConfig(
    filename="app.log",
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

logging.debug("This is a debug message")
logging.info("This is an info message")
logging.warning("This is a warning message")
logging.error("This is an error message")
logging.critical("This is a critical message")

logging.shutdown()
