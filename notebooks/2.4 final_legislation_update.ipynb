# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from DataObjects.article import Article
from DataObjects.legislation import Legislation, ArticleMapping
from DataObjects.public_consultation import PublicConsultation
from DataObjects.base import Base
from typing import Any
import functools
import requests
import re
from sqlalchemy import create_engine, select, union_all, func, delete, and_
from sqlalchemy.orm import Session, aliased
from typing import Callable
from bs4 import BeautifulSoup
import os
from configparser import ConfigParser
from datetime import datetime
config = ConfigParser()
config.read("config.ini")
from pathlib import Path
import csv

engine = create_engine(config.get('DEFAULT', 'db_file'))

# %%
def scrap_hellenic_parliament_url(url:str) -> dict[str,str]:
    
    r2 = requests.get(url)

    legislation_soup = BeautifulSoup(r2.content, features="html.parser")

    data={}

    title = legislation_soup.find(string='Τίτλος').next_element.find('dd').string
    data["title"] = title

    legislation_type = legislation_soup.find(string='Τύπος').next_element.find('dd').string if legislation_soup.find(string='Τύπος') is not None else None
    data["legislation_type"] = legislation_type

    ministry = legislation_soup.find(string="Υπουργείο").next_element.find('dd').string if legislation_soup.find(string='Υπουργείο') is not None else None
    data["ministry"] = ministry

    fek_number = legislation_soup.find(string="Αριθμός Φεκ").next_element.find('dd').string if legislation_soup.find(string='Αριθμός Φεκ') is not None else None
    data["fek_number"] = fek_number

    law_number = legislation_soup.find(string="Αριθμός Νόμου").next_element.find('dd').string if legislation_soup.find(string='Αριθμός Νόμου') is not None else None
    data["law_number"] = law_number

    date_posted = legislation_soup.find(string="Ημ. Ψήφισης").next_element.find('dd').string if legislation_soup.find(string='Ημ. Ψήφισης') is not None else None
    date_posted = datetime.strptime(date_posted,"%d/%m/%Y") if date_posted is not None else None
    data["date_posted"] = date_posted

    legislation_url = legislation_soup.find(string="Ψηφισθέν Νομοσχέδιο").next_element.find('a').get('href') if legislation_soup.find(string='Ψηφισθέν Νομοσχέδιο') is not None else None
    data["legislation_pdf_url"] = legislation_url

    data["scrap_url"] = r2.url

    return data

# %%
pdf_directory = Path.cwd() / "pdf_files"
with open('final_legislation_data_cleaning.csv','r', encoding='utf-8-sig') as f:
    reader = csv.reader(f, delimiter=';')
    #row[0]:id
    #row[2]:HellenicParliamentURL
    #row[3]:LegislationType
    #row[4]:NoFinalLegislationReason
    #row[7]:ArticleMappingStart
    #row[8]:FinalLegislationArticle


    with Session(engine) as sess:
        for row in reader:
            if row[0]=="270":  # DEBUG
                print()
            if row[0]=="ID":  # if Header Row, Skip
                continue
            print(f"Current row {row[0]}")
            stmt = select(Legislation).where(Legislation.id==row[0])

            publicConsultationObj:Legislation = sess.execute(stmt).scalar_one()
            # Update Legislation Type or NoFinalLegislationReason
            if row[3]:
                publicConsultationObj.legislation_type = row[3]
            if row[4]:
                publicConsultationObj.no_final_legislation_reason = row[4]
            sess.commit()

            # if Final Legislation already exists, it is assumed to be wrong
            # delete pdf file
            if publicConsultationObj.final_legislation:
                file_name = f"{publicConsultationObj.final_legislation_id}.pdf"
                pdf_file = pdf_directory / file_name
                # print(pdf_file)
                if pdf_file.exists():
                    pdf_file.unlink()
                sess.delete(publicConsultationObj.final_legislation)
                sess.commit()

            #if final Legislation Link exists in csv
            if row[2]:
                #check if link already exists in database
                stmt2 = select(Legislation).where(Legislation.scrap_url==row[2]).order_by(Legislation.id.asc())
                legObj2 = sess.execute(stmt2).scalars().first()   
                # if final_legislation does not exists 
                if not legObj2:
                    final_legislation_data = scrap_hellenic_parliament_url(row[2])
                    finalLegObj = Legislation(**final_legislation_data)
                    sess.add(finalLegObj)
                    publicConsultationObj.final_legislation = finalLegObj
                    sess.commit()
                
                else:  # if the final legislation is already in DB
                    #update Law Num
                    final_legislation_data = scrap_hellenic_parliament_url(row[2])
                    legObj2.law_number = final_legislation_data["law_number"]

                    publicConsultationObj.final_legislation= legObj2
                    sess.commit()

            # if article Mapping Exists, create a new Article Mapping
            if row[7] and row[8]:
                try:
                    PublicConsultationArticleNum = int(row[7])
                    FinalLegislationArticleNum = int(row[8])
                except ValueError as e:
                    print(f"Invalid Value: {e}")
                    continue

                data = {}
                data["legislation_id"] = publicConsultationObj.id
                data["public_consultation_article_no"] = PublicConsultationArticleNum
                data["final_legislation_article_no"] =FinalLegislationArticleNum

                articleMappingObj = ArticleMapping(**data)
                sess.add(articleMappingObj)
                sess.commit()
# Out:
# Current row 18
# Current row 41
# Current row 48
# Current row 61
# Current row 64
# Current row 97
# Current row 106
# Current row 116
# Current row 117
# Current row 123
# Current row 126
# Current row 145
# Current row 149
# Current row 151
# Current row 153
# Current row 196
# Current row 214
# Current row 223
# Current row 229
# Current row 237
# Current row 253
# Current row 260
# Current row 267
# Current row 268
#
# Current row 270
# Current row 272
# Current row 282
# Current row 295
# Current row 296
# Current row 299
# Current row 308
# Current row 327
# Current row 339
# Current row 342
# Current row 348
# Current row 358
# Current row 364
# Current row 390
# Current row 405
# Current row 408
# Current row 410
# Current row 411
# Current row 422
# Current row 423
# Current row 424
# Current row 425
# Current row 433
# Current row 434
# Current row 435
# Current row 437
# Current row 439
# Current row 447
# Current row 470
# Current row 480
# Current row 481
# Current row 511
# Current row 516
# Current row 536
# Current row 557
# Current row 590
# Current row 591
# Current row 604
# Current row 634
# Current row 649
# Current row 676
# Current row 692
# Current row 694
# Current row 736
# Current row 766
# Current row 767
# Current row 771
# Current row 774
# Current row 791
# Current row 822
# Current row 869
# Current row 40
# Current row 192
# Current row 269
# Current row 273
# Current row 280
# Current row 334
# Current row 346
# Current row 446
# Current row 455
# Current row 461
# Current row 467
# Current row 490
# Current row 517
# Current row 520
# Current row 568
# Current row 677
# Current row 693
# Current row 720
# Current row 760
# Current row 7
# Current row 28
# Current row 35
# Current row 72
# Current row 162
# Current row 165
# Current row 171
# Current row 180
# Current row 181
# Current row 203
# Current row 204
# Current row 206
# Current row 209
# Current row 231
# Current row 235
# Current row 240
# Current row 252
# Current row 255
# Current row 276
# Current row 277
# Current row 283
# Current row 290
# Current row 307
# Current row 315
# Current row 333
# Current row 343
# Current row 375
# Current row 415
# Current row 429
# Current row 443
# Current row 468
# Current row 489
# Current row 491
# Current row 492
# Current row 507
# Current row 508
# Current row 512
# Current row 518
# Current row 538
# Current row 543
# Current row 681
# Current row 813
# Current row 856
# Current row 876
# Current row 4
# Current row 9
# Current row 17
# Current row 22
# Current row 26
# Current row 50
# Current row 55
# Current row 58
# Current row 59
# Current row 60
# Current row 99
# Current row 101
# Current row 102
# Current row 103
# Current row 104
# Current row 107
# Current row 109
# Current row 112
# Current row 113
# Current row 114
# Current row 118
# Current row 125
# Current row 127
# Current row 132
# Current row 150
# Current row 169
# Current row 170
# Current row 172
# Current row 173
# Current row 174
# Current row 183
# Current row 198
# Current row 199
# Current row 200
# Current row 202
# Current row 207
# Current row 215
# Current row 244
# Current row 245
# Current row 246
# Current row 248
# Current row 256
# Current row 257
# Current row 259
# Current row 262
# Current row 264
# Current row 265
# Current row 266
# Current row 271
# Current row 286
# Current row 293
# Current row 297
# Current row 300
# Current row 302
# Current row 328
# Current row 330
# Current row 331
# Current row 336
# Current row 338
# Current row 340
# Current row 341
# Current row 344
# Current row 347
# Current row 350
# Current row 353
# Current row 356
# Current row 366
# Current row 369
# Current row 370
# Current row 383
# Current row 402
# Current row 403
# Current row 409
# Current row 420
# Current row 421
# Current row 428
# Current row 431
# Current row 445
# Current row 448
# Current row 451
# Current row 453
# Current row 460
# Current row 464
# Current row 466
# Current row 469
# Current row 472
# Current row 473
# Current row 476
# Current row 493
# Current row 495
# Current row 502
# Current row 513
# Current row 515
# Current row 527
# Current row 534
# Current row 541
# Current row 547
# Current row 551
# Current row 552
# Current row 555
# Current row 560
# Current row 561
# Current row 564
# Current row 571
# Current row 572
# Current row 584
# Current row 585
# Current row 587
# Current row 588
# Current row 594
# Current row 596
# Current row 603
# Current row 605
# Current row 617
# Current row 619
# Current row 620
# Current row 622
# Current row 623
# Current row 626
# Current row 627
# Current row 629
# Current row 631
# Current row 638
# Current row 639
# Current row 640
# Current row 641
# Current row 642
# Current row 646
# Current row 655
# Current row 663
# Current row 664
# Current row 667
# Current row 668
# Current row 669
# Current row 675
# Current row 690
# Current row 706
# Current row 707
# Current row 722
# Current row 725
# Current row 731
# Current row 734
# Current row 746
# Current row 749
# Current row 750
# Current row 753
# Current row 758
# Current row 759
# Current row 768
# Current row 776
# Current row 786
# Current row 788
# Current row 798
# Current row 799
# Current row 803
# Current row 809
# Current row 811
# Current row 816
# Current row 817
# Current row 819
# Current row 821
# Current row 823
# Current row 847
# Current row 850
# Current row 862
# Current row 865
# Current row 867
# Current row 871
# Current row 874
# Current row 877
# Current row 130
# Current row 133
# Current row 158
# Current row 166
# Current row 175
# Current row 176
# Current row 177
# Current row 184
# Current row 185
# Current row 186
# Current row 195
# Current row 205
# Current row 210
# Current row 217
# Current row 222
# Current row 261
# Current row 287
# Current row 288
# Current row 311
# Current row 316
# Current row 320
# Current row 335
# Current row 349
# Current row 352
# Current row 355
# Current row 367
# Current row 368
# Current row 376
# Current row 377
# Current row 378
# Current row 389
# Current row 392
# Current row 398
# Current row 414
# Current row 417
# Current row 419
# Current row 426
# Current row 452
# Current row 456
# Current row 457
# Current row 474
# Current row 477
# Current row 479
# Current row 482
# Current row 487
# Current row 494
# Current row 501
# Current row 545
# Current row 554
# Current row 565
# Current row 573
# Current row 583
# Current row 592
# Current row 597
# Current row 606
# Current row 610
# Current row 611
# Current row 615
# Current row 632
# Current row 645
# Current row 656
# Current row 660
# Current row 661
# Current row 662
# Current row 666
# Current row 672
# Current row 674
# Current row 682
# Current row 685
# Current row 687
# Current row 708
# Current row 711
# Current row 716
# Current row 721
# Current row 723
# Current row 728
# Current row 729
# Current row 730
# Current row 733
# Current row 737
# Current row 739
# Current row 740
# Current row 743
# Current row 744
# Current row 747
# Current row 748
# Current row 751
# Current row 755
# Current row 757
# Current row 761
# Current row 763
# Current row 769
# Current row 775
# Current row 779
# Current row 781
# Current row 784
# Current row 785
# Current row 793
# Current row 794
# Current row 800
# Current row 807
# Current row 838
# Current row 841
# Current row 844
# Current row 853
# Current row 860
# Current row 863
# Current row 879
# Current row 2
# Current row 6
# Current row 21
# Current row 44
# Current row 47
# Current row 53
# Current row 56
# Current row 57
# Current row 65
# Current row 73
# Current row 74
# Current row 75
# Current row 76
# Current row 77
# Current row 80
# Current row 81
# Current row 82
# Current row 85
# Current row 86
# Current row 87
# Current row 88
# Current row 89
# Current row 93
# Current row 96
# Current row 98
# Current row 105
# Current row 156
# Current row 157
# Current row 159
# Current row 161
# Current row 163
# Current row 164
# Current row 167
# Current row 169
# Current row 170
# Current row 178
# Current row 188
# Current row 190
# Current row 194
# Current row 208
# Current row 211
# Current row 212
# Current row 213
# Current row 220
# Current row 221
# Current row 224
# Current row 225
# Current row 238
# Current row 242
# Current row 251
# Current row 274
# Current row 275
# Current row 278
# Current row 279
# Current row 284
# Current row 285
# Current row 289
# Current row 292
# Current row 294
# Current row 298
# Current row 304
# Current row 305
# Current row 306
# Current row 318
# Current row 322
# Current row 326
# Current row 332
# Current row 337
# Current row 345
# Current row 351
# Current row 360
# Current row 361
# Current row 365
# Current row 371
# Current row 380
# Current row 381
# Current row 385
# Current row 388
# Current row 395
# Current row 397
# Current row 400
# Current row 401
# Current row 404
# Current row 407
# Current row 413
# Current row 418
# Current row 427
# Current row 432
# Current row 440
# Current row 450
# Current row 454
# Current row 463
# Current row 465
# Current row 471
# Current row 475
# Current row 496
# Current row 498
# Current row 500
# Current row 509
# Current row 510
# Current row 522
# Current row 523
# Current row 524
# Current row 525
# Current row 526
# Current row 528
# Current row 531
# Current row 535
# Current row 540
# Current row 542
# Current row 553
# Current row 566
# Current row 567
# Current row 570
# Current row 575
# Current row 577
# Current row 580
# Current row 595
# Current row 599
# Current row 600
# Current row 608
# Current row 613
# Current row 614
# Current row 616
# Current row 628
# Current row 630
# Current row 633
# Current row 635
# Current row 636
# Current row 637
# Current row 647
# Current row 648
# Current row 651
# Current row 652
# Current row 654
# Current row 657
# Current row 658
# Current row 659
# Current row 665
# Current row 671
# Current row 678
# Current row 679
# Current row 680
# Current row 683
# Current row 684
# Current row 686
# Current row 688
# Current row 689
# Current row 709
# Current row 710
# Current row 712
# Current row 713
# Current row 715
# Current row 717
# Current row 719
# Current row 724
# Current row 726
# Current row 727
# Current row 735
# Current row 738
# Current row 741
# Current row 742
# Current row 745
# Current row 754
# Current row 756
# Current row 762
# Current row 764
# Current row 765
# Current row 772
# Current row 777
# Current row 782
# Current row 783
# Current row 787
# Current row 789
# Current row 790
# Current row 792
# Current row 797
# Current row 801
# Current row 802
# Current row 804
# Current row 808
# Current row 814
# Current row 815
# Current row 828
# Current row 830
# Current row 831
# Current row 833
# Current row 834
# Current row 836
# Current row 840
# Current row 846
# Current row 852
# Current row 858
# Current row 859
# Current row 861
# Current row 866
# Current row 872
# Current row 873
# Current row 154
# Current row 189
# Current row 249
# Current row 263
# Current row 281
# Current row 313
# Current row 317
# Current row 357
# Current row 362
# Current row 363
# Current row 393
# Current row 485
# Current row 499
# Current row 533
# Current row 556
# Current row 601
# Current row 602
# Current row 714
# Current row 806
# Current row 559
# Current row 607
# Current row 826
# Current row 25
# Current row 63
# Current row 111
# Current row 219
# Current row 319
# Current row 324
# Current row 412
# Current row 497
# Current row 514
# Current row 519
# Current row 530
# Current row 539
# Current row 546
# Current row 558
# Current row 579
# Current row 718
# Current row 795
# Current row 827
# Current row 855
# Current row 857
# Current row 136
# Current row 143
# Current row 160
# Current row 179
# Current row 232
# Current row 241
# Current row 436
# Current row 505
# Current row 550
# Current row 810
# Current row 478
# Current row 569
# Current row 612
# Current row 14
# Current row 394
# Current row 441
# Current row 444
# Current row 537
# Current row 780
# Current row 851
# Current row 854

# %%
import pprint

# %%
# Update Correct Legislations with Law Number
# Update Public Consultation LegislationType = 'Bill'

with Session(engine) as sess:
    stmt = select(Legislation).where(and_(
        ~Legislation.final_legislation_id.is_(None),
        Legislation.legislation_type.is_(None)
        ))

    print(stmt)
    results = sess.execute(stmt).scalars()

    for legObj in results:
        legObj:Legislation
        print(f"Current Legislation {legObj.id}")

        legObj.legislation_type = "Bill"
        finalLegislationObj = legObj.final_legislation
        data = scrap_hellenic_parliament_url(finalLegislationObj.scrap_url)
        finalLegislationObj.law_number = data["law_number"]

        sess.commit()
# Out:
# SELECT "Legislation".id, "Legislation".title, "Legislation".ministry, "Legislation".date_posted, "Legislation".parliament_url, "Legislation".legislation_pdf_url, "Legislation".scrap_url, "Legislation".final_legislation_id, "Legislation".gov_gazzete_number, "Legislation".legislation_type, "Legislation".law_number, "Legislation".no_final_legislation_reason
# FROM "Legislation"
# WHERE "Legislation".final_legislation_id IS NOT NULL AND "Legislation".legislation_type IS NULL
# Current Legislation 1
# Current Legislation 3
# Current Legislation 5
# Current Legislation 8
# Current Legislation 10
# Current Legislation 11
# Current Legislation 12
# Current Legislation 13
# Current Legislation 15
# Current Legislation 16
# Current Legislation 19
# Current Legislation 20
# Current Legislation 23
# Current Legislation 24
# Current Legislation 27
# Current Legislation 29
# Current Legislation 30
# Current Legislation 31
# Current Legislation 32
# Current Legislation 33
# Current Legislation 34
# Current Legislation 36
# Current Legislation 37
# Current Legislation 38
# Current Legislation 39
# Current Legislation 42
# Current Legislation 43
# Current Legislation 45
# Current Legislation 46
# Current Legislation 49
# Current Legislation 51
# Current Legislation 52
# Current Legislation 54
# Current Legislation 62
# Current Legislation 66
# Current Legislation 67
# Current Legislation 68
# Current Legislation 69
# Current Legislation 70
# Current Legislation 71
# Current Legislation 78
# Current Legislation 79
# Current Legislation 83
# Current Legislation 84
# Current Legislation 90
# Current Legislation 91
# Current Legislation 92
# Current Legislation 94
# Current Legislation 95
# Current Legislation 100
# Current Legislation 108
# Current Legislation 110
# Current Legislation 115
# Current Legislation 119
# Current Legislation 120
# Current Legislation 121
# Current Legislation 122
# Current Legislation 124
# Current Legislation 128
# Current Legislation 129
# Current Legislation 131
# Current Legislation 134
# Current Legislation 135
# Current Legislation 137
# Current Legislation 138
# Current Legislation 139
# Current Legislation 140
# Current Legislation 141
# Current Legislation 142
# Current Legislation 144
# Current Legislation 146
# Current Legislation 147
# Current Legislation 148
# Current Legislation 152
# Current Legislation 155
# Current Legislation 168
# Current Legislation 182
# Current Legislation 187
# Current Legislation 191
# Current Legislation 193
# Current Legislation 197
# Current Legislation 201
# Current Legislation 216
# Current Legislation 218
# Current Legislation 226
# Current Legislation 227
# Current Legislation 228
# Current Legislation 230
# Current Legislation 233
# Current Legislation 234
# Current Legislation 236
# Current Legislation 239
# Current Legislation 243
# Current Legislation 247
# Current Legislation 250
# Current Legislation 254
# Current Legislation 258
# Current Legislation 291
# Current Legislation 301
# Current Legislation 303
# Current Legislation 309
# Current Legislation 310
# Current Legislation 312
# Current Legislation 314
# Current Legislation 321
# Current Legislation 323
# Current Legislation 325
# Current Legislation 329
# Current Legislation 354
# Current Legislation 359
# Current Legislation 372
# Current Legislation 373
# Current Legislation 374
# Current Legislation 379
# Current Legislation 382
# Current Legislation 384
# Current Legislation 386
# Current Legislation 387
# Current Legislation 391
# Current Legislation 396
# Current Legislation 399
# Current Legislation 406
# Current Legislation 416
# Current Legislation 430
# Current Legislation 438
# Current Legislation 442
# Current Legislation 449
# Current Legislation 458
# Current Legislation 459
# Current Legislation 462
# Current Legislation 483
# Current Legislation 484
# Current Legislation 486
# Current Legislation 488
# Current Legislation 503
# Current Legislation 504
# Current Legislation 506
# Current Legislation 521
# Current Legislation 529
# Current Legislation 532
# Current Legislation 544
# Current Legislation 548
# Current Legislation 549
# Current Legislation 562
# Current Legislation 563
# Current Legislation 574
# Current Legislation 576
# Current Legislation 578
# Current Legislation 581
# Current Legislation 582
# Current Legislation 586
# Current Legislation 589
# Current Legislation 593
# Current Legislation 598
# Current Legislation 609
# Current Legislation 618
# Current Legislation 621
# Current Legislation 624
# Current Legislation 625
# Current Legislation 643
# Current Legislation 644
# Current Legislation 650
# Current Legislation 653
# Current Legislation 670
# Current Legislation 673
# Current Legislation 691
# Current Legislation 695
# Current Legislation 732
# Current Legislation 752
# Current Legislation 770
# Current Legislation 773
# Current Legislation 778
# Current Legislation 796
# Current Legislation 805
# Current Legislation 812
# Current Legislation 818
# Current Legislation 820
# Current Legislation 824
# Current Legislation 825
# Current Legislation 829
# Current Legislation 832
# Current Legislation 835
# Current Legislation 837
# Current Legislation 839
# Current Legislation 842
# Current Legislation 843
# Current Legislation 845
# Current Legislation 848
# Current Legislation 849
# Current Legislation 864
# Current Legislation 868
# Current Legislation 870
# Current Legislation 875
# Current Legislation 878
# Current Legislation 880

# %% [markdown]
# Download PDF Files

# %%
# Download Pdf Files
# Update "Not found" with Bill as Legislation Type --> OK
# Add new 10 rows of data from excel
# update "Νόμος" to 'Bill' --> OK
# Create a check that indicates if a Legislation is publicConsulation or Not

# %%
PDF_PATH ="pdf_files"
with Session(engine) as sess:
    stmt = select(Legislation).where(Legislation.id.in_(
        select(Legislation.final_legislation_id).where(~Legislation.final_legislation_id.is_(None))
    ))
    print(stmt)

    legObjs = sess.execute(stmt).scalars()

    for legObj in legObjs:
        # print(os.path.join(PDF_PATH,f"{str(legObj.id)}.pdf"))
        if not legObj.legislation_pdf_url:
            continue
        with open(os.path.join(PDF_PATH,f"{str(legObj.id)}.pdf"),'wb') as pdffile:
            response = requests.get(legObj.legislation_pdf_url) 
            pdffile.write(response.content)
# Out:
# SELECT "Legislation".id, "Legislation".title, "Legislation".ministry, "Legislation".date_posted, "Legislation".parliament_url, "Legislation".legislation_pdf_url, "Legislation".scrap_url, "Legislation".final_legislation_id, "Legislation".gov_gazzete_number, "Legislation".legislation_type, "Legislation".law_number, "Legislation".no_final_legislation_reason
# FROM "Legislation"
# WHERE "Legislation".id IN (SELECT "Legislation".final_legislation_id
# FROM "Legislation"
# WHERE "Legislation".final_legislation_id IS NOT NULL)

# %%
pdf_directory = Path.cwd() / "pdf_files"
pdf_file = pdf_directory / "899.pdf"

# pdf_file.unlink delets file
# Out:
# True

# %%
import pprint

# %%
url = "https://www.hellenicparliament.gr/Nomothetiko-Ergo/Anazitisi-Nomothetikou-Ergou?law_id=1b038d3c-8f1f-41bc-b6a6-4afecd4e488c"

data = scrap_hellenic_parliament_url(url)
pprint.pprint(data)
# Out:
# {'date_posted': datetime.datetime(2013, 11, 28, 0, 0),
#  'gov_gazzete_number': "261 A'/ 09.12.2013",
#  'law_number': '4213',
#  'legislation_pdf_url': 'https://www.hellenicparliament.gr/UserFiles/bcc26661-143b-4f2d-8916-0e0e66ba4c50/p-asthen-pap.pdf',
#  'legislation_type': 'Νόμος',
#  'ministry': 'Υγείας',
#  'scrap_url': 'https://www.hellenicparliament.gr/Nomothetiko-Ergo/Anazitisi-Nomothetikou-Ergou?law_id=1b038d3c-8f1f-41bc-b6a6-4afecd4e488c',
#  'title': 'Προσαρμογή της εθνικής νομοθεσίας στις διατάξεις της Οδηγίας '
#           '2011/24/ΕΕ του  Ευρωπαϊκού Κοινοβουλίου και του Συμβουλίου της 9ης '
#           'Μαρτίου 2011 περί εφαρμογής των δικαιωμάτων των ασθενών στο πλαίσιο '
#           'της διασυνοριακής υγειονομικής  περίθαλψης (L88/45/ 4.4.2011) και '
#           'άλλες διατάξεις.'}
