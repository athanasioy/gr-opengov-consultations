# %%
import pdfplumber
from pathlib import Path
import glob
import re
import pprint
from collections import defaultdict
import logging
from datetime import datetime

# %%
from DataObjects.article import Article
from DataObjects.legislation import Legislation
from DataObjects.public_consultation import PublicConsultation
from DataObjects.base import Base
from sqlalchemy import create_engine, select, union_all, func, delete, and_
from sqlalchemy.orm import Session, aliased
from configparser import ConfigParser
config = ConfigParser()
config.read("config.ini")
engine = create_engine(config.get('DEFAULT', 'db_file'))

# %%
#Pending Files
txt_files_full = glob.glob("pdf_files/text/*_full.txt")

with Session(engine) as sess:
    stmt = select(Article.legislation_id).where(Article.legislation_id>890).distinct()
    legIds = sess.execute(stmt).scalars().all()
# print(legIds)
for f in txt_files_full:
    if not any((str(legID) in f for legID in legIds)):
        print(str(f))

gibberish = ['1231','1442','995']
# Out:
# pdf_files/text\1089_full.txt
# pdf_files/text\1231_full.txt
# pdf_files/text\1442_full.txt
# pdf_files/text\898_full.txt
# pdf_files/text\995_full.txt

# %%
bills_with_full_text_article_numbers = set(
    ('1279',
    '1247',
    
    '1296',
    '1307',
    '1376',
    '1418',
    '1423')
)

bills_with_inproper_spacing = set(
    ('1255',
    '1442')
)
extempted_from_analysis = [('898','Page 25,30 of pdf.pages have invisible characters in the middle of the screen and misclasify two-column pages as one column.'),
                           ('1089','Page 7 keeps extracting "/" character in the middle  even though bounding box nears an area of zero ((295.5,366,301.8,759.5))'),
                           ('1231','Gibberish extracted')]

# %%
logging.basicConfig(filename="pdf_extract.log",
                    filemode='a',
                    format='%(asctime)s - %(levelname)s - %(message)s',level=logging.INFO,
                    encoding='utf-8')

# %%
pdf_files_txt = glob.glob("pdf_files/*.pdf")
pdf_files = [Path(pdf_file) for pdf_file in pdf_files_txt]
print(all(pdf_file.exists() for pdf_file in pdf_files))  # check if PathObjs are correctly set up
# Out:
# True

# %% [markdown]
# Extract text from PDF

# %%
to_do_again = ['1005',
'1023',
'1081',
'1176',
'1235',
'1237',
'1239',
'1240',
'1243',
'1246',
'1247',
'1248',
'1249',
'1250',
'1251',
'1252',
'1253',
'1254',
'1255',
'1259',
'1260',
'1262',
'1263',
'1265',
'1267',
'1272',
'1273',
'1282',
'1284',
'1285',
'1322',
'1323',
'1325',
'1330',
'1339',
'1344',
'1358',
'1415',
'1432',
'1433',
'1434',
'1438',
'1439',
'1440',
'1441',
'1442',
'1443',
'1444',
'1445',
'1448',
'1457',
'894',
'897',
'901',
'902',
'907',
'942',
'957',
'959',
'961',
'963',
'977',
'982',
'984',
'990',
'992',
'994'
]

one_column_list =[ "898",
"1089","1296","1279","1376","1418","1423","1247","1391","1407",
]

# %%
# Page Width: 595
# Page Height: 842
txt_files_dir = "pdf_files/text"
for pdf in pdf_files:  #Second run from 53  third run from 70 forth run frm 217
    # print(f"Current File {pdf.stem}")
    with pdfplumber.open(pdf) as f:
        # if pdf.stem not in to_do_again:
        #     continue

        if pdf.stem not in one_column_list:
            continue
        print(f"Current File {pdf.stem}")

        #scrap article numbers and titles
        txt_articles = ""
        txt_full = ""
        now = datetime.now()
        current_time = now.strftime("%H:%M:%S")
        for idx, page in enumerate(f.pages):
            # print(f"Page {idx}")
            p = page.filter(lambda obj: obj["object_type"] == "char" and "Bold" in obj["fontname"])
            if p.width - 595 >1 or p.height - 842 > 1:
                logging.info(msg=f"Page {idx+1}(of {len(f.pages)}) has differnt width or height from usual page. File={pdf.name}, pWidth={p.width}, pHeight={p.height}")
                continue
            box_check_for_one_column = (300,65,301.8,759.5)
            box_check_for_one_column_first_page = (300,400,301.8,759.5)
            one_column_bbox =(0,64,p.width,799)
            one_column_bbox_first_page =(0,400,p.width,799)
            # bbox=(x0,top,x1,bottom) [(0,0) is bottom left]
            # coordinates found with GIMP
            one_column = False
            if idx==0:  #First Page
                
                if page.crop(box_check_for_one_column_first_page).extract_text(): # if text exists in the middle of the page
                    one_column = True
            else:
                if page.crop(box_check_for_one_column).extract_text(): # if text exists in the middle of the page
                    one_column = True
            if one_column == False:
                if idx==0:  # if First Page
                    left_articles = p.crop((0, 366, 0.5 * float(p.width), 779))
                    right_articles = p.crop((0.5 * float(p.width), 366, p.width, 779))

                    left_full = page.crop((0, 366, 0.5 * float(p.width), 779))
                    right_full = page.crop((0.5 * float(p.width), 366, p.width, 779))
                else:
                    left_articles = p.crop((0, 64, 0.5 * float(p.width), 779))
                    right_articles = p.crop((0.5 * float(p.width), 64, p.width, 779))

                    left_full = page.crop((0, 64, 0.5 * float(p.width), 779))
                    right_full = page.crop((0.5 * float(p.width), 64, p.width, 779))
                
                txt_articles +="\n"+ left_articles.extract_text()
                txt_articles +="\n"+ right_articles.extract_text()

                txt_full += "\n" + left_full.extract_text()
                txt_full += "\n" + right_full.extract_text()
            else:
                if idx ==0:
                    page_articles = p.crop(one_column_bbox_first_page)
                    page_full = page.crop(one_column_bbox_first_page)
                else:
                    page_articles = p.crop(one_column_bbox)
                    page_full = page.crop(one_column_bbox)
                
                txt_articles +="\n"+ page_articles.extract_text()
                txt_full += "\n" + page_full.extract_text()
            
        now = datetime.now()
        current_time = now.strftime("%H:%M:%S")
        print(f"Done With Text Extraction at {current_time}")


        txt_articles += "\nΆρθρ"  # Add this so we have a match on the last article
        # txt_full += "Ά"  # Add this so we have a match on the last article
        # matches_articles = re.findall(article_nums_digits_pattern,txt_articles,re.DOTALL)
        now = datetime.now()
        current_time = now.strftime("%H:%M:%S")
        # print(f"Done With ReGEx at {current_time}")

        #Write txt to files
        txt_articles_file = Path("pdf_files") / "text" / f"{pdf.stem}_articles.txt"
        # if not txt_articles_file.exists():
        txt_articles_file.touch()
        txt_articles_file.write_text(txt_articles,encoding="utf-8")
        
        txt_full_file = Path("pdf_files") / "text" / f"{pdf.stem}_full.txt"
        # if not txt_full_file.exists():
        txt_full_file.touch()
        txt_full_file.write_text(txt_full,encoding="utf-8")
# Out:
# Current File 1089
# Done With Text Extraction at 20:31:53
# Current File 1247
# Done With Text Extraction at 20:32:07
# Current File 1279
# Done With Text Extraction at 20:32:35
# Current File 1296
# Done With Text Extraction at 20:32:46
# Current File 1376
# Done With Text Extraction at 20:32:50
# Current File 1391
# Done With Text Extraction at 20:34:06
# Current File 1407
# Done With Text Extraction at 20:34:45
# Current File 1418
# Done With Text Extraction at 20:34:46
# Current File 1423
# Done With Text Extraction at 20:35:02
# Current File 898
# Done With Text Extraction at 20:35:30

# %% [markdown]
# Read text, extract articles and Save to DB

# %%
txt_files_articles = glob.glob("pdf_files/text/*_articles.txt")
txt_files_full = glob.glob("pdf_files/text/*_full.txt")

end_of_bill1 = "Ο ΠΡΟΕΔΡΟ" # Ο ΠΡΟΕΔΡΟΣ ΤΗΣ ΒΟΥΛΗΣ
end_of_bill2= "ΠΑΡΑΡ" # ΠΑΡΑΡΤΗΜΑ

for txt_articles_file, txt_full_file in zip(txt_files_articles,txt_files_full):  # (100)1255: Άρθρο1
    # Read Text Files
    # tested on 
    print(f"Text File {txt_full_file}")
    txt_articles = Path(txt_articles_file).read_text(encoding='utf-8')
    txt_articles += "ρθρ"  #Necessary in order to match last article due to regex changes on the positive lookahead (?=Ά) = (?=Άρθρ)
    txt_full = Path(txt_full_file).read_text(encoding='utf-8')

    # article_nums_digits_pattern= r"(?<!«)Άρθρο\s?(\d+)(.*?)(:?(?=Ά)|(?=ΚΕΦΑ)|(?=ΜΕΡΟΣ))"
    # article_nums_digits_pattern = r"^Άρθρο\s?(\d+)(.*?)(:?(?=Ά)|(?=ΚΕΦΑ)|(?=ΜΕΡΟΣ))"
    # article_nums_digits_pattern = r"^Άρθρο\s?(\d+)(.*?)(:?(?=Άρθ)|(?=ΚΕΦΑ)|(?=ΜΕΡΟΣ))"

    # change positve lookahead because (?=Ά) falsely disregarded article titles that started with Ά
    article_nums_digits_pattern = r"^Άρθρ[οo]\s?(\d+)(.*?)(:?(?=Άρθρ)|(?=ΚΕΦΑ)|(?=ΜΕΡΟΣ))"  #id=892 Άρθρο 95 has a Latin "o" 

    matches_articles = re.findall(article_nums_digits_pattern,txt_articles,re.DOTALL| re.MULTILINE)

    # Create Article Dict
    articles_dict = {}
    for match in matches_articles:
        articles_dict[match[0]] = match[1]

    data = defaultdict(dict)
    try:
        max_article_num = max((int(x) for x in articles_dict.keys()))
        min_article_num = min((int(x) for x in articles_dict.keys()))
    except ValueError as e:
        logging.log(logging.INFO, f"File={txt_articles_file} - Empty Sequence. Msg={str(e)} ")
        continue

    if sorted((int(x) for x in articles_dict.keys())) != list(range(min_article_num,max_article_num+1)):
        # raise ValueError(f"Missing Article Numbers {set(range(min_article_num,max_article_num+1)).difference(set(sorted((int(x) for x in articles_dict.keys()))))}")
        logging.log(logging.INFO, f"File={txt_articles_file} Missing Article Numbers {set(range(min_article_num,max_article_num+1)).difference(set(sorted((int(x) for x in articles_dict.keys()))))}")
        continue

    break_to_outer_loop = False
    for k in articles_dict.keys():

        current_article_num = int(k)
        next_article_num = current_article_num+1

        
        # article_text_start_idx = txt_full.rfind(article_text_start)  # We need the last occurance of Άρθρο \d+\n
        # article_text_start = articles_dict[k].strip()

        # Try to match by Article No. And Title
        article_text_start = f"Άρθρο {current_article_num}{articles_dict[str(current_article_num)]}".strip()
        article_text_start_idx = txt_full.find(article_text_start)
        flag_use_full_title_in_search=True

        # If no result, match by Article No. Only
        if article_text_start_idx==-1:
            # if matching  by title fails, match by article
            # 1310 => Article 2 has hidden text
            article_text_start = f"Άρθρο {current_article_num}\n"
            article_text_start_idx = txt_full.find(article_text_start)
            flag_use_full_title_in_search = False
        
        if article_text_start_idx==-1:
            # id=892 => Match by Latin "o"
            article_text_start = f"Άρθρo {current_article_num}\n"
            article_text_start_idx = txt_full.find(article_text_start)
            flag_use_full_title_in_search = False

        # If still no result, try with no whitespace between Article and No (caused by improper text extraction)
        if article_text_start_idx==-1:
            # 1362 => Άρθρο 10 is outputed as 'Άρθρο10'
            article_text_start = f"Άρθρο{current_article_num}\n"
            article_text_start_idx = txt_full.find(article_text_start)

        if article_text_start_idx==-1:
            logging.log(logging.INFO,f"File={txt_articles_file}Cannot find text {article_text_start} in full_text")
            break_to_outer_loop=True

        if current_article_num!=max_article_num:
            # article_text_end = f"Άρθρο {next_article_num}\n"
            article_text_end = f"Άρθρο {next_article_num}{articles_dict[str(next_article_num)]}".strip()
            # article_text_end_idx = txt_full.rfind(article_text_end)
            article_text_end_idx = txt_full.find(article_text_end)

            if article_text_end_idx==-1:
                # if None, try to match only the article number
                article_text_end = f"Άρθρο {next_article_num}".strip()
                article_text_end_idx = txt_full.find(article_text_end)
            
            if article_text_end_idx==-1:
                # id=892 => Match by Latin "o"
                article_text_end = f"Άρθρo {next_article_num}".strip()
                article_text_end_idx = txt_full.find(article_text_end)

            if article_text_end_idx==-1:
                # if None, try to match only the article number without whitespace
                article_text_end = f"Άρθρο{next_article_num}".strip()
                article_text_end_idx = txt_full.find(article_text_end)

            if article_text_end_idx==-1:
                logging.log(logging.INFO,f"File={txt_articles_file} Cannot find text {article_text_end} in full_text")
                # raise ValueError(f"Cannot find text {article_text_end} in full_text")
                break_to_outer_loop=True


        else:
            if txt_full.rfind(end_of_bill2)>0 :
                article_text_end_idx = txt_full.rfind(end_of_bill2) # ΠΑΡΑΡΤΗΜΑ
            elif txt_full.rfind(end_of_bill1)>0:
                article_text_end_idx = txt_full.rfind(end_of_bill1) # Ο ΠΡΟΕΔΡΟΣ
            else:
                article_text_end_idx = len(txt_full)
                
        article_text = txt_full[article_text_start_idx+len(article_text_start):article_text_end_idx]
        if flag_use_full_title_in_search==False:
            article_text = article_text.replace(articles_dict[k].strip(),"",1)  #remove title from text

        data[k].update({'title': articles_dict[k]})
        data[k].update({'text': article_text})
    
    if break_to_outer_loop:
        logging.log(logging.INFO, f"File={txt_articles_file} did not continue to DB Save due to previous error")
        continue

    with Session(engine) as sess:
        try:
            legislation_id = re.search(r"\d+",txt_articles_file)[0]
            stmt = select(Legislation).where(Legislation.id==legislation_id)
            legObj = sess.execute(stmt).scalar_one()

            for article,textAndTitle in data.items():
                articleObj = Article(number=article,title=textAndTitle['title'], text=textAndTitle['text'])
                if articleObj.number not in (legiglationArticlesObj.number for legiglationArticlesObj in legObj.articles):
                    legObj.articles.append(articleObj)
            sess.commit()
        except:
            logging.log(logging.INFO, f"File={txt_articles_file} Failed to save to DB.")
# Out:
# Text File pdf_files/text\1000_full.txt
"1350",
"1352",
"1366",
"1379",
"1383",
"1388",
"1389",
"1402",
"1419",
"1426",
"1427",
"1442",
"897",
"898",
"939",
"948",
"949","1247","1307","1376","1418","1423"
"974",
"999"]

# %% [markdown]
# Extract Articles and DB Save

# %%
bills_with_full_text_article_numbers = set(
    ('1279',
     '1176',
     '1391',
    '1247',
    '1423',
    '1235',
    '1247',
    '1296',
    '1307',
    '1407',
    '1376',
    '1418',
    '1423')
)

# %%
from textUtils.textDecorators import text_to_numeric

# %% [markdown]
# Extract Articles and DB Save Final with fully written articles

# %%
txt_files_articles = glob.glob("pdf_files/text/*_articles.txt")
txt_files_full = glob.glob("pdf_files/text/*_full.txt")

end_of_bill1 = "Ο ΠΡΟΕΔΡΟ" # Ο ΠΡΟΕΔΡΟΣ ΤΗΣ ΒΟΥΛΗΣ
end_of_bill2= "ΠΑΡΑΡ" # ΠΑΡΑΡΤΗΜΑ

for txt_articles_file, txt_full_file in zip(txt_files_articles,txt_files_full):  # (100)1255: Άρθρο1
    # if not any((to_do_txt_file in txt_articles_file for to_do_txt_file in txt_files_to_do_again)):
    #     continue
    if not any((to_do_txt_file in txt_articles_file for to_do_txt_file in bills_with_full_text_article_numbers)):
        continue
    
    full_text_article_flag = False
    print(f"Text File {txt_full_file}")    
    txt_articles = Path(txt_articles_file).read_text(encoding='utf-8')
    txt_articles += "ρθρ"  #Necessary in order to match last article due to regex changes on the positive lookahead (?=Ά) = (?=Άρθρ)
    txt_full = Path(txt_full_file).read_text(encoding='utf-8')

    if "1307" in txt_articles_file:
        print()
    # change positve lookahead because (?=Ά) falsely disregarded article titles that started with Ά
    # article_nums_digits_pattern = r"^Άρθρ[οo]\s?(\d+)(.*?)(:?(?=Άρθρ)|(?=ΚΕΦΑ)|(?=ΜΕΡΟΣ))"  #id=892 Άρθρο 95 has a Latin "o" 
    if any((to_do_txt_file in txt_articles_file for to_do_txt_file in bills_with_full_text_article_numbers)):
        articles_full_text_pattern = r"^[ΆΑA]ρθρ[οo]\s?([\w\s]*?)\n(.*?)(:?(?=[ΆΑA]ρθρ)|(?=ΚΕΦΑ)|(?=ΜΕΡΟΣ))"
        full_text_article_flag = True
 
    article_nums_digits_pattern = r"^[ΆΑA]ρθρ[οo]\s?(\d+)(.*?)(:?(?=[ΆΑA]ρθρ)|(?=ΚΕΦΑ)|(?=ΜΕΡΟΣ))"  #id=892 Άρθρο 95 has a Latin "o" 
        
    matches_articles = re.findall(article_nums_digits_pattern,txt_articles,re.DOTALL| re.MULTILINE)
    articles_dict = {}

    #Text To Numeric Mapping for Full Text Articles
    if full_text_article_flag:
        txt_to_numeric = {}
        matches_full_text = re.findall(articles_full_text_pattern, txt_articles,re.DOTALL|re.MULTILINE)
        for m in matches_full_text:
            article_num_integer = text_to_numeric(m[0])
            original_text = m[0]
            article_title = m[1]
            if article_num_integer== -1:
                raise ValueError(f"Text To Numeric Failed for PDF={txt_articles_file}, txt={m[0]}")
            txt_to_numeric[original_text] = article_num_integer
            articles_dict[original_text] = m[1] 
    else:
        # Create Article Dict
        for match in matches_articles:
            articles_dict[match[0]] = match[1]

    if "1383" in txt_articles_file:
        articles_dict[70] = "Article 70 Does not Exist in 1383!!!!!!"
    

    data = defaultdict(dict)
    if full_text_article_flag:
        try:
            max_article_num = max((int(x) for x in txt_to_numeric.values()))
            min_article_num = min((int(x) for x in txt_to_numeric.values()))
        except ValueError as e:
            logging.log(logging.INFO, f"File={txt_articles_file} - Empty Sequence. Msg={str(e)} ")
            continue
    else:
        try:
            max_article_num = max((int(x) for x in articles_dict.keys()))
            min_article_num = min((int(x) for x in articles_dict.keys()))
        except ValueError as e:
            logging.log(logging.INFO, f"File={txt_articles_file} - Empty Sequence. Msg={str(e)} ")
            continue
    
    if full_text_article_flag:
        sorted_articles = sorted((int(x) for x in txt_to_numeric.values()))
    else:
        sorted_articles = sorted((int(x) for x in articles_dict.keys()))

    if sorted_articles != list(range(min_article_num,max_article_num+1)):
        # raise ValueError(f"Missing Article Numbers {set(range(min_article_num,max_article_num+1)).difference(set(sorted((int(x) for x in articles_dict.keys()))))}")
        logging.log(logging.INFO, f"File={txt_articles_file} Missing Article Numbers {set(range(min_article_num,max_article_num+1)).difference(set(sorted_articles))}")
        continue

    break_to_outer_loop = False
    if full_text_article_flag:
        articles_array = list(sorted(articles_dict.keys(),key=lambda x: text_to_numeric(x)))
        max_article_num = articles_array[len(articles_array)-1]
    else:
        articles_array = list(sorted(articles_dict.keys(),key=lambda x: int(x)))
        articles_array = list((int(x) for x in articles_array))


    for idx,k in enumerate(articles_array):

        current_article_num = k
        if current_article_num==70 and "1383" in txt_articles_file:
            continue # 1383=> Article 70 does not Exist!
        if idx < len(articles_array)-1:
            next_article_num = articles_array[idx+1]
        
        if next_article_num==70 and "1383" in txt_articles_file:  #if next article is 70, go to 71
            next_article_num =articles_array[idx+1+1]  # 1383=> Article 70 does not Exist!

        
        # article_text_start_idx = txt_full.rfind(article_text_start)  # We need the last occurance of Άρθρο \d+\n
        # article_text_start = articles_dict[k].strip()

        # Try to match by Article No. And Title
        article_text_start = f"Άρθρο {current_article_num}{articles_dict[str(current_article_num)]}".strip()
        article_text_start_idx = txt_full.find(article_text_start)
        flag_use_full_title_in_search=True

        # If no result, match by Article No. Only
        if article_text_start_idx==-1:
            # if matching  by title fails, match by article
            # 1310 => Article 2 has hidden text
            # id=892 => Match by Latin "o"
        # If still no result, try with no whitespace between Article and No (caused by improper text extraction)
            # 1362 => Άρθρο 10 is outputed as 'Άρθρο10'
            flag_use_full_title_in_search = False
            m = re.search(r"[ΆΑA]ρθρ[οo]\s?"+str(current_article_num)+"\n",txt_full)
            if m is not None:
                article_text_start_idx = m.start()    

        if article_text_start_idx==-1:
            logging.log(logging.INFO,f"File={txt_articles_file}Cannot find text {article_text_start} in full_text")
            break_to_outer_loop=True

        if current_article_num!=max_article_num:
            # article_text_end = f"Άρθρο {next_article_num}\n"
            article_text_end = f"Άρθρο {next_article_num}{articles_dict[str(next_article_num)]}".strip()
            # article_text_end_idx = txt_full.rfind(article_text_end)
            article_text_end_idx = txt_full.find(article_text_end)

            if article_text_end_idx==-1:
                # if None, try to match only the article number
                m = re.search(r"[ΆΑA]ρθρ[οo]\s?"+str(next_article_num)+"\n",txt_full)
                if m is not None:
                    article_text_end_idx = m.start()    
                    article_text_end = m.group()

            if article_text_end_idx==-1:
                logging.log(logging.INFO,f"File={txt_articles_file} Cannot find text {article_text_end} in full_text")
                # raise ValueError(f"Cannot find text {article_text_end} in full_text")
                break_to_outer_loop=True

        else:
            if txt_full.rfind(end_of_bill2)>0 :
                article_text_end_idx = txt_full.rfind(end_of_bill2) # ΠΑΡΑΡΤΗΜΑ
            elif txt_full.rfind(end_of_bill1)>0:
                article_text_end_idx = txt_full.rfind(end_of_bill1) # Ο ΠΡΟΕΔΡΟΣ
            else:
                article_text_end_idx = len(txt_full)
                
        article_text = txt_full[article_text_start_idx+len(article_text_start):article_text_end_idx]

        if flag_use_full_title_in_search==False:  # if seach did not use full article title, try to remove on this step
            article_text = article_text.replace(articles_dict[str(current_article_num)].strip(),"",1)  #remove title from text

        data[k].update({'title': articles_dict[str(current_article_num)]})
        data[k].update({'text': article_text})
    
    if break_to_outer_loop:
        logging.log(logging.INFO, f"File={txt_articles_file} did not continue to DB Save due to previous error")
        continue

    with Session(engine) as sess:
        try:
            legislation_id = re.search(r"\d+",txt_articles_file)[0]
            stmt = select(Legislation).where(Legislation.id==legislation_id)
            legObj = sess.execute(stmt).scalar_one()

            for article,textAndTitle in data.items():
                article_num: int
                if full_text_article_flag:
                    article_num = text_to_numeric(article)
                else:
                    article_num = article
                articleObj = Article(number=article_num,title=textAndTitle['title'], text=textAndTitle['text'])
                if full_text_article_flag:
                    # print(articleObj)
                if articleObj.number not in (legiglationArticlesObj.number for legiglationArticlesObj in legObj.articles):
                    legObj.articles.append(articleObj)
            sess.commit()
        except:
            logging.log(logging.INFO, f"File={txt_articles_file} Failed to save to DB.")
# Out:
# Text File pdf_files/text\1176_full.txt
# Article(id=None, number=1, title=Κύρωση Σύµβασης και του
# συνοδευτικού αυτής Πρωτοκόλλου
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# , text=υ
# Κυρώνονται και έχουν την ισχύ, που ορίζει η παρ., legislation_id=None)
# Article(id=None, number=2, title=Κατάργηση ν.δ. 4386/1964
# , text=4
# Από τη θέση σε ισχύ της Σύµβασης που κυρώνεται,
# , legislation_id=None)
# Article(id=None, number=3, title=Έναρξη ισχύος
#
# , text=ς
# Η ισχύς του παρόντος νόµου αρχίζει από τη δηµοσί, legislation_id=None)
# Text File pdf_files/text\1235_full.txt
# Article(id=None, number=1, title=
#
# , text=
# Κυρώνεται και αποκτά ισχύ νόμου από τη δημοσίευσή, legislation_id=None)
# Article(id=None, number=2, title=, text=
# Στην εξαίρεση από την αναστολή της παραγράφου 2
# τ, legislation_id=None)
# Article(id=None, number=3, title=, text=
# Οι διατάξεις της παραγράφου 4 του άρθρου 28 του
# ν, legislation_id=None)
# Article(id=None, number=4, title=, text=
# 1. Η προθεσμία της παραγράφου 6 του άρθρου 10 του, legislation_id=None)
# Text File pdf_files/text\1247_full.txt
# Article(id=None, number=1, title=Σύσταση εταιρείας
# , text=ς
# 1. Συνιστάται ανώνυμη εταιρεία με την επωνυμία «, legislation_id=None)
# Article(id=None, number=2, title=Καταστατικό
#
#
#
#
#
#
#
#
#
# , text=ό
# Το  της Εταιρείας έχει ως εξής:
# «ΚΑΤΑΣΤΑΤΙΚΟ
# ΚΕΦ, legislation_id=None)
# Article(id=None, number=3, title=Περιουσία - Υφιστάμενες δικαιοπραξίες
# Εκκρεμείς δίκες
# , text=ς
# 1. Από την έναρξη ισχύος του παρόντος, η ΤΕΜΠΜΕ
# , legislation_id=None)
# Article(id=None, number=4, title=Κανονισμοί λειτουργίας
# , text=ς
# 1. Εντός διμήνου από τη δημοσίευση του παρόντος , legislation_id=None)
# Article(id=None, number=5, title=Θέματα προσωπικού
# , text=ύ
# 1. Το προσωπικό, που υπηρετεί κατά τη δημοσίευση, legislation_id=None)
# Article(id=None, number=6, title=Έργα - Προμήθειες - Υπηρεσίες
# , text=ς
# Οι όροι και οι διαδικασίες ανάθεσης μελετών, εκτ, legislation_id=None)
# Article(id=None, number=7, title=Απαλλαγές - προνόμια
# , text=α
# Η Εταιρεία δεν υπόκειται σε φόρο συγκέντρωσης κε, legislation_id=None)
# Article(id=None, number=8, title=Μεταβατικές διατάξεις
# , text=ς
# 1. Μέχρι τη σύγκληση της Γενικής Συνέλευσης, το , legislation_id=None)
# Article(id=None, number=9, title=Τροποποίηση του ν. 3775/2009
# , text=9
# Στο τέλος της παραγράφου 7 του άρθρου 22 του
# ν. , legislation_id=None)
# Article(id=None, number=10, title=Τροποποίηση διατάξεων για την άσκηση
# του επαγγέλματος του Λογιστή Φοροτεχνικού
# , text=ύ
# 1. Η περίπτωση β΄ της παραγράφου 1 του άρθρου 1
# , legislation_id=None)
# Article(id=None, number=11, title=Εγγραφή μελών στο Οικονομικό
# Επιμελητήριο της Ελλάδος
# , text=ς
# 1. Η παράγραφος 3 του άρθρου 3 του ν. 1100/1980,, legislation_id=None)
# Article(id=None, number=12, title=Αναμόρφωση Εθνικού Συμβουλίου
# Ανταγωνιστικότητας και Ανάπτυξης
#
#
#
#
# , text=ς
# 1. Το δεύτερο εδάφιο της παραγράφου 1 του άρθρου, legislation_id=None)
# Article(id=None, number=13, title=Τροποποίηση του άρθρου 2 παρ.1 του ν. 1796/1988
# , text=8
# Η περίπτωση θ΄ της παρ.1 του άρθρου 2 του ν.1796, legislation_id=None)
# Article(id=None, number=14, title=Έναρξη ισχύος
# , text=ς
# Η ισχύς του παρόντος νόμου αρχίζει από τη δημοσί, legislation_id=None)
# Text File pdf_files/text\1279_full.txt
# Article(id=None, number=1, title=Α. Στην Αγγλική γλώσσα:
# Council of Europe Treaty Series - No. 215
# Council of Europe Convention on the Manipulation of Sports Competitions
# Preamble
#
# Chapter I – Purpose, guiding principles, definitions
# Article 1 – Purpose and main objectives
# Article 2 – Guiding principles
# Article 3 – Definitions
# Chapter II – Prevention, co-operation and other measures
# Article 4 – Domestic co-ordination
# Article(id=None, number=6, title=Τροποποίηση του άρθρου 27 του ν. 2725/1999 (Α΄ 121)
# «Κανονισµοί»
# , text=»
# Το άρθρο 27 του ν. 2725/1999 τροποποιείται ως εξ, legislation_id=None)
# Article(id=None, number=7, title=Αναστολή ισχύος διατάξεων που εισήχθησαν
# µε τον ν. 4603/2019 (Α΄ 48)
# , text=)
# 1. Αναστέλλεται η ισχύς των κάτωθι διατάξεων έως, legislation_id=None)
# Article(id=None, number=8, title=Τροποποίηση του άρθρου 22 του ν. 2725/1999 (Α΄ 121)
# «Διοικητικό Συµβούλιο»
# , text=»
# Η παράγραφος 7 του άρθρου 22 του ν. 2725/1999, η, legislation_id=None)
# Article(id=None, number=9, title=Τροποποίηση του άρθρου 56 του ν. 2725/1999 (Α΄ 121)
# «Ρύθµιση θεµάτων γυµναστηρίων και λοιπών
# αθλητικών εγκαταστάσεων»
# , text=»
# Στο άρθρο 56 του ν. 2725/1999 προστίθεται νέα πα, legislation_id=None)
# Article(id=None, number=10, title=Ορισµός Επιτροπής Διοίκησης
# Καυταντζογλείου Σταδίου
# , text=υ
# Η παράγραφος 2 του άρθρου 6 του ν. 423/1976
# (Α΄2, legislation_id=None)
# Article(id=None, number=11, title=Εναρµόνιση της αθλητικής νοµοθεσίας
# µε τον ν. 4548/2018 (Α΄ 104)
# , text=)
# 1. Όπου στον ν. 2725/1999 (Α΄ 121), όπως έχει τρ, legislation_id=None)
# Article(id=None, number=12, title=Τροποποίηση του άρθρου 25 του ν. 4325/2015 (Α΄ 47)
# , text=)
# Η παράγραφος 1 του άρθρου 25 του ν. 4325/2015 τρ, legislation_id=None)
# Article(id=None, number=13, title=Καταστατικό της Ε.Ο.Ε.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# , text=.
# 1. Ο αθλητικός οργανισµός που ιδρύθηκε στις 24 Ν, legislation_id=None)
# Article(id=None, number=14, title=Οργανόγραµµα - προσωπικό Ε.Ο.Ε.
# , text=.
# 1. Η Ε.Ο.Ε. υποχρεούται να καταρτίσει Εσωτερικό , legislation_id=None)
# Article(id=None, number=15, title=Απαλλαγές – προνόµια
# , text=α
# 1. Η Ε.Ο.Ε. απολαµβάνει των δικαστικών ατελειών , legislation_id=None)
# Article(id=None, number=16, title=Τροποποιούµενες διατάξεις
# , text=ς
# 1. Ο τίτλος του άρθρου 37 του ν. 2725/1999 (Α΄ 1, legislation_id=None)
# Article(id=None, number=17, title=Καταργούµενες διατάξεις
# , text=ς
# Με την έναρξη ισχύς του παρόντος καταργούνται:
# (, legislation_id=None)
# Article(id=None, number=18, title=Μνηµόνιο Συναντίληψης και Συνεργασίας
# , text=ς
# Στο άρθρο 43 του ν. 3905/2010 (Α΄ 219) προστίθεν, legislation_id=None)
# Article(id=None, number=19, title=Θέση του Ταµείου Αλληλοβοηθείας Υπαλλήλων
# Υπουργείου Πολιτισµού και Αθλητισµού
# σε εκκαθάριση
#
# , text=η
# 1. Το Ταµείο Αλληλοβοηθείας Υπαλλήλων Υπουργείου, legislation_id=None)
# Article(id=None, number=20, title=Προσωπικό Ταµείου Αρχαιολογικών
# Πόρων και Απαλλοτριώσεων
# , text=ν
# Το πρώτο εδάφιο της παραγράφου 4 του άρθρου 5 το, legislation_id=None)
# Article(id=None, number=21, title=Έναρξη ισχύος
# , text=ς
# 1. Η ισχύς του παρόντος νόµου αρχίζει από τη δηµ, legislation_id=None)
# Text File pdf_files/text\1296_full.txt
# Article(id=None, number=1, title=, text=
# Κυρώνεται και έχει την ισχύ που ορίζει το άρθρο 2, legislation_id=None)
# Article(id=None, number=2, title=Τροποποιήσεις του Ποινικού Κώδικα
# (, text=(Άρθρα 2, 3, 4, 5, 6, 7, 9 παράγραφοι 2, 3
# και 4 τ, legislation_id=None)
# Article(id=None, number=3, title=Τροποποιήσεις του ν. 2225/1994
# , text=4
# 1. Η παρ. 1 του άρθρου 4 του ν. 2225/1994 αντικα, legislation_id=None)
# Article(id=None, number=4, title=Ευθύνη νοµικών προσώπων
# (, text=(Άρθρο 11 της Οδηγίας)
# 1. Αν κάποια από τις πράξει, legislation_id=None)
# Article(id=None, number=5, title=Δήλωση κατ΄ άρθρο 27 της Σύµβασης
# , text=ς
# Η Ελληνική Δηµοκρατία ορίζει ως αρµόδια αρχή σύµ, legislation_id=None)
# Article(id=None, number=6, title=Δήλωση κατ’ άρθρο 35 της Σύµβασης
# και 13 παράγραφος 1 της Οδηγίας
# , text=ς
# Η Ελληνική Δηµοκρατία ορίζει ως σηµείο επαφής γι, legislation_id=None)
# Article(id=None, number=7, title=Δήλωση κατ’ άρθρο 42 της Σύµβασης
# , text=ς
# Η Ελληνική Δηµοκρατία διατυπώνει, κατά το άρθρο , legislation_id=None)
# Article(id=None, number=8, title=Παραγραφή και παύση ποινικής δίωξης
# , text=ς
# 1. Εξαλείφεται το αξιόποινο και παύει η δίωξη τω, legislation_id=None)
# Article(id=None, number=9, title=Παραγραφή και µη εκτέλεση ποινών υπό όρο
# , text=ο
# 1. Ποινές διάρκειας µέχρι έξι (6) µηνών που έχου, legislation_id=None)
# Article(id=None, number=10, title=Ρυθµίσεις για την Εθνική Σχολή
# Δικαστικών Λειτουργών
#
# , text=ν
# 1. Η περίπτωση γ΄ της παρ. 2 του άρθρου 13 του ν, legislation_id=None)
# Article(id=None, number=11, title=Τροποποίηση διατάξεων του ν. 1756/1988 (Α΄ 35)
# , text=)
# 1. Το έκτο εδάφιο της παρ. 4 του άρθρου 15 του
# ν, legislation_id=None)
# Article(id=None, number=12, title=Σύσταση Επιτροπών για τη σύνταξη νέου Κώδικα
# Οργανισµού Δικαστηρίων και Κατάστασης Δικαστικών
# Λειτουργών και νέου Κώδικα Δικαστικών Υπαλλήλων
# , text=ν
# 1. Στο Υπουργείο Δικαιοσύνης, Διαφάνειας και Ανθ, legislation_id=None)
# Article(id=None, number=13, title=Ενίσχυση Σωφρονιστικής Διοίκησης
# , text=ς
# H παρ. 1 του άρθρου 44 του ν. 4356/2015 (Α΄181) , legislation_id=None)
# Article(id=None, number=14, title=Εργασιακά θέµατα υπαλλήλων
# Καταστηµάτων Κράτησης
# , text=ς
# 1. α) Ο αριθµός των ωρών νυχτερινής απασχόλησης
# , legislation_id=None)
# Article(id=None, number=15, title=Παράταση ρυθµίσεων του ν. 4322/2015
# , text=5
# 1. Η παρ. 4 του άρθρου 12 του ν. 4322/2015 (Α΄42, legislation_id=None)
# Article(id=None, number=16, title=Εξουσιοδοτική διάταξη σχετικα µε το Αναµορφωτικό
# Μέτρο της Παροχής Κοινωφελούς Εργασίας
# , text=ς
# Με απόφαση του Υπουργού Δικαιοσύνης, Διαφάνειας
# , legislation_id=None)
# Article(id=None, number=17, title=Θέµατα εξωτερικής φρουράς Καταστηµάτων Κράτησης
# , text=ς
# 1. Στο τέλος της παρ. 1 του άρθρου 48 του
# ν. 272, legislation_id=None)
# Article(id=None, number=18, title=Ρυθµίσεις για τρίτεκνους
#
# , text=ς
# 1. Η περίπτωση ε΄ της παρ. 1 του άρθρου 1 του
# ν., legislation_id=None)
# Article(id=None, number=19, title=Εξουσιοδοτική διάταξη για την προστασία µαρτύρων
# , text=ν
# Η παρ. 3 του άρθρου 9 του ν. 2928/2001 (Α΄ 141) , legislation_id=None)
# Article(id=None, number=20, title=Συµπλήρωση παραγράφου στο άρθρο 192
# του ν. 4389/2016
# , text=6
# Η παρ. 8 του άρθρου 192 του ν. 4389/2016 (Α΄ 94), legislation_id=None)
# Article(id=None, number=21, title=Μεταβατικές διατάξεις
# , text=ς
# Μέχρι την επιλογή και τοποθέτηση προϊσταµένου
# στ, legislation_id=None)
# Article(id=None, number=22, title=, text=
# 1. Οι οφειλόµενες δαπάνες παρελθόντων ετών για
# ύδ, legislation_id=None)
# Article(id=None, number=23, title=, text=
# 1. Το εδάφιο δ΄της παρ. 5 του άρθρου 3 του
# ν. 305, legislation_id=None)
# Article(id=None, number=24, title=, text=
# Η παρ. 2 του άρθρου 147 του Κώδικα Πολιτικής Δικο, legislation_id=None)
# Article(id=None, number=25, title=, text=
# 1. Το εδάφιο τρίτο της περίπτωσης β΄ της παρ. 3 τ, legislation_id=None)
# Article(id=None, number=26, title=Τροποποιήσεις στο ν. 4194/2013 (Α΄208)
# «Κώδικας Δικηγόρων»
#
# , text=»
# 1. Στο πρώτο εδάφιο της παρ. 6 του άρθρου 30 του, legislation_id=None)
# Article(id=None, number=27, title=
# , text=
# 1. Το στοιχείο 1 της υποπαραγράφου Ι.Δ.1 της παρ., legislation_id=None)
# Article(id=None, number=28, title=, text=
# 1. Στον Οργανισµό Απασχολήσεως Εργατικού Δυναµι-
# , legislation_id=None)
# Article(id=None, number=29, title=, text=
# Με απόφαση του Γενικού Γραµµατέα Δηµοσίων Εσό-
# δω, legislation_id=None)
# Article(id=None, number=30, title=, text=
# Στην παρ. 9 του άρθρου 38 του ν. 4387/2016 (Α΄ 85, legislation_id=None)
# Article(id=None, number=31, title=Αντισταθµιστικά µέτρα κατάργησης ΕΚΑΣ
#
# , text=Σ
# 1. Σε όσους, κατ’ εφαρµογή του άρθρου 92 του
# ν. , legislation_id=None)
# Article(id=None, number=32, title=Έναρξη ισχύος
# , text=ς
# Η ισχύς του παρόντος νόµου αρχίζει από τη δηµοσί, legislation_id=None)
# Text File pdf_files/text\1307_full.txt
#
# Article(id=None, number=1, title=Εισαγωγή συστήµατος αµοιβών νοσοκοµείων επί τη
# βάσει ολοκληρωµένου συστήµατος κατανοµής αµοιβής
# ανά περιστατικό
#
#
# , text=ό
# 1. Εισάγεται στο χώρο της υγείας το Σύστηµα Αµοι, legislation_id=None)
# Article(id=None, number=2, title=Αποστολή στοιχείων διοικητικού και ιατρικού φακέλου
# ασθενών από τα δηµόσια νοσοκοµεία και
# τις ιδιωτικές κλινικές
# , text=ς
# Για τη δηµιουργία και τη διαρκή ανάπτυξη του Σ.Α, legislation_id=None)
# Article(id=None, number=3, title=Αποστολή αρχείων κόστους νοσηλείας ασθενών
# από τα δηµόσια νοσοκοµεία
# , text=α
# Εκτός από την υποχρέωση του δεύτερου άρθρου του
# , legislation_id=None)
# Article(id=None, number=4, title=Αποστολή αρχείων κόστους νοσηλείας ασθενών
# από ιδιωτικές κλινικές
# , text=ς
# Η Ε.Σ.Α.Ν. Α.Ε. µεριµνά για τη συλλογή των αντίσ, legislation_id=None)
# Article(id=None, number=5, title=Αποστολή αρχείων ασθενών από τον Εθνικό
# Οργανισµό Παροχής Υπηρεσιών Υγείας (ΕΟΠΥΥ)
# και τα υπόλοιπα ασφαλιστικά ταµεία
# , text=α
# Ο ΕΟΠΥΥ, καθώς και κάθε άλλο δηµόσιο ταµείο, υπό, legislation_id=None)
# Article(id=None, number=6, title=Σύσταση - Μορφή Ε.Σ.Α.Ν. Α.Ε.
# , text=.
# 1. Συνιστάται ανώνυµη εταιρεία µη κερδοσκοπικού
# , legislation_id=None)
# Article(id=None, number=7, title=Mετοχικό κεφάλαιο
# , text=ο
# 1. Το µετοχικό κεφάλαιο της Εταιρείας ανέρχεται , legislation_id=None)
# Article(id=None, number=8, title=Πόροι
# , text=ι
# 1. Οι πόροι της Εταιρείας είναι:
# α) Τα έσοδα από, legislation_id=None)
# Article(id=None, number=9, title=Ατέλειες
# , text=ς
# Η Εταιρεία απολαµβάνει όλων των διοικητικών, οικ, legislation_id=None)
# Article(id=None, number=10, title=Καταστατικό της Εταιρείας
#
#
#
#
#
#
#
#
#
#
#
#
#
# , text=ς
# Το  έχει ως εξής:
# «ΚΕΦΑΛΑΙΟ ΠΡΩΤΟ
# ΣΥΣΤΑΣΗ - ΕΠΩΝ, legislation_id=None)
# Article(id=None, number=11, title=Τροποποίηση του Παραρτήµατος ΙΙΙ του π.δ. 26/2008
# (παράρτηµα 1 της Οδηγίας 2012/39/ΕE)
# , text=)
# Η παράγραφος 1.2 του παραρτήµατος IΙI του π.δ.
# 2, legislation_id=None)
# Article(id=None, number=12, title=Τροποποίηση του παραρτήµατος IV του π.δ. 26/2008
# (παράρτηµα 2 της Οδηγίας 2012/39/ΕE)
# , text=)
# 1. Η παράγραφος 2.4 του παραρτήµατος ΙV του π.δ., legislation_id=None)
# Article(id=None, number=13, title=
# , text=
# Α) Μεταφορά προσωπικού και ρύθµιση οικονοµικών
# θε, legislation_id=None)
# Article(id=None, number=14, title=, text=
# 1. Η παρ. 4 του άρθρου 5 του π.δ. 237/1986 (Α΄ 11, legislation_id=None)
# Article(id=None, number=15, title=, text=
# Μετά το άρθρο 65 του ν. 4001/2011 (Α΄ 179) προστί, legislation_id=None)
# Article(id=None, number=16, title=Ρυθµίσεις για την αντιµετώπιση των εξαιρετικά
# επειγουσών και απρόβλεπτων αναγκών του µη
# κερδοσκοπικού ιδρύµατος µε την επωνυµία
# «ΚΟΙΝΩΦΕΛΕΣ ΙΔΡΥΜΑ ΕΡΡΙΚΟΣ ΝΤΥΝΑΝ ΝΠΙΔ»
# και του σωµατείου «ΕΛΛΗΝΙΚΟΣ ΕΡΥΘΡΟΣ ΣΤΑΥΡΟΣ»
# , text=»
# 1. Παρατείνεται η προθεσµία του άρθρου 11 του
# ν., legislation_id=None)
# Article(id=None, number=17, title=Μεταφορά µαθητών δηµόσιων σχολείων
# , text=ν
# 1. Εάν και µετά τους πρόχειρους διαγωνισµούς του, legislation_id=None)
# Article(id=None, number=18, title=, text= ντα χιλιάδων (150.000) ευρώ για τον έγγαµο και το, legislation_id=None)
# Article(id=None, number=19, title=Εξόφληση οφειλών Φορέων Υγείας εποπτευόµενων
# από το Υπουργείο Εθνικής Άµυνας για προµήθειες
# Ειδών Ιατροφαρµακευτικής Περίθαλψης
# , text=ς
# Η ισχύς των προβλεπόµενων από τις διατάξεις της , legislation_id=None)
# Article(id=None, number=20, title=, text=
# 1. Η παρ. 2 του άρθρου 15 του ν. 1756/1988, όπως , legislation_id=None)
# Article(id=None, number=21, title=, text=
# Δικαιώµατα προαιρέσεως σε συµβάσεις που έχουν
# συν, legislation_id=None)
# Article(id=None, number=22, title=, text=
# Για την άµεση εκπλήρωση διεθνών υποχρεώσεων της
# χ, legislation_id=None)
# Article(id=None, number=23, title=Έναρξη ισχύος
# , text=ς
# Η ισχύς του παρόντος νόµου αρχίζει από τη δηµοσί, legislation_id=None)
# Text File pdf_files/text\1376_full.txt
# Article(id=None, number=2, title=, text=
# 1. Οι διατάξεις του άρθρου 6 δεν δεσµεύουν την Ελ, legislation_id=None)
# Article(id=None, number=3, title=, text=
# Με προεδρικά διατάγµατα που εκδίδονται µε πρόταση, legislation_id=None)
# Article(id=None, number=4, title=, text=
# Η ισχύς του νόµου αυτού αρχίζει από τη δηµοσίευσή, legislation_id=None)
# Text File pdf_files/text\1391_full.txt
# Article(id=None, number=1, title=ν. 4046/2012 και άλλες διατάξεις
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ΠΙΝΑΚΑΣ Α΄
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# , text=οσό τετρακοσίων πενήντα εκατοµµυ-
# ρίων (450.000.00, legislation_id=None)
# Article(id=None, number=2, title=
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# , text=
# ΠΑΡΑΓΡΑΦΟΣ Α: ΤΡΟΠΟΠΟΙΗΣΕΙΣ Ν. 3864/2010 «ΠΕ-
# ΡΙ , legislation_id=None)
# Article(id=None, number=3, title=
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# , text=
# περιορισµών του Ταµείου στην άσκηση των δικαιωµάτ, legislation_id=None)
# Article(id=None, number=4, title=Έναρξη ισχύος
# , text=ς
# Η ισχύς του νόµου αυτού αρχίζει από τη δηµοσίευσ, legislation_id=None)
# Text File pdf_files/text\1407_full.txt
# Article(id=None, number=1, title=
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# , text=
# ΠΑΡΑΓΡΑΦΟΣ Α
# ΤΡΟΠΟΠΟΙΗΣΗ ΔΙΑΤΑΞΕΩΝ
# Ν.Δ. 356/1974,, legislation_id=None)
# Article(id=None, number=2, title=Έναρξη ισχύος
# , text=, legislation_id=None)
# Text File pdf_files/text\1418_full.txt
# Article(id=None, number=2, title=Σύσταση Εθνικού Μηχανισµού Πρόληψης
# , text=ς
# 1. Ως «Εθνικός Μηχανισµός Πρόληψης», κατά τα άρ-, legislation_id=None)
# Article(id=None, number=3, title=Στελέχωση Εθνικού Μηχανισµού Πρόληψης
# , text=ς
# 1. Για την άσκηση των αρµοδιοτήτων που προβλέπο-, legislation_id=None)
# Article(id=None, number=4, title=Διενέργεια επισκέψεων – Πραγµατογνωµοσύνη
# , text=η
# 1. Κατά την ενάσκηση των καθηκόντων του, ο Εθνικ, legislation_id=None)
# Article(id=None, number=5, title=Σύνταξη εκθέσεων
# , text=ν
# Στην παρ. 5 του άρθρου 3 του ν. 3094/2003 (Α΄ 10, legislation_id=None)
# Article(id=None, number=6, title=, text=
# Οι δαπάνες που προκαλούνται από τη λειτουργία του, legislation_id=None)
# Article(id=None, number=7, title=, text= , legislation_id=None)
# Article(id=None, number=8, title=, text=
# Με απόφαση του Συνηγόρου του Πολίτη που δηµοσι- Η, legislation_id=None)
# Text File pdf_files/text\1423_full.txt
# Article(id=None, number=1, title=
#
# , text=
# Το κεφάλαιο ΣΤ΄ του Μέρους Δ΄ του Υπαλληλικού Κώ-, legislation_id=None)
# Article(id=None, number=2, title=
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# , text=
# Το Μέρος Ε΄ του Υπαλληλικού Κώδικα (ν. 3528/2007,, legislation_id=None)
# Article(id=None, number=3, title=, text=
# 1. Η παρ. 7 του άρθρου 10 του ν. 4024/2011 (Α΄ 22, legislation_id=None)
# Article(id=None, number=4, title=, text=
# 1. Οι διατάξεις του παρόντος νόµου, που αναφέροντ, legislation_id=None)
# Article(id=None, number=5, title=, text=
# 1. Οι διατάξεις του παρόντος νόµου, που αναφέροντ, legislation_id=None)
# Article(id=None, number=6, title=Ρυθµίσεις πειθαρχικών θεµάτων εκπαιδευτικών
# και λοιπού προσωπικού αρµοδιότητας του
# Υπουργείου Παιδείας, Δια Βίου Μάθησης
# και Θρησκευµάτων
#
#
#
# , text=ν
# 1. Με απόφαση του Υπουργού Παιδείας, Δια Βίου Μά, legislation_id=None)
# Article(id=None, number=7, title=Μεταβατικές διατάξεις
# , text=ς
# 1. Για τα πειθαρχικά παραπτώµατα που τελούνται µ, legislation_id=None)
# Article(id=None, number=8, title=Καταργούµενες διατάξεις
# , text=ς
# 1. Καταργείται κάθε διάταξη των νόµων 3528/2007,, legislation_id=None)
# Article(id=None, number=9, title=Θέµατα αρµοδιότητας του Υπουργείου Διοικητικής
# Μεταρρύθµισης και Ηλεκτρονικής Διακυβέρνησης
#
#
#
#
#
#
#
# , text=ς
# 1. Η κατάργηση ή συγχώνευση οργανικής µονάδας ε-, legislation_id=None)
# Article(id=None, number=10, title=Έναρξη ισχύος
# , text=ς
# Η ισχύς του παρόντος νόµου αρχίζει από τη δηµοσί, legislation_id=None)

# %%
with pdfplumber.open("pdf_files/898.pdf") as f:
    p_oneColumn = f.pages[12]
    p_twoColums = f.pages[5]
    # bbox=(x0,top,x1,bottom) [(0,0) is bottom left]
    # coordinates found with GIMP
    box_check_for_one_column = (291.5,60,303.8,759.5)
    box_check_for_one_column_first_page = (291.5,366,303.8,759.5)
    one_column_bbox =(0,64,p_oneColumn.width,799)
    p_oneColumn_crop = p_oneColumn.crop(box)
    p_twoColums_crop = p_twoColums.crop(box)
    print("One Column Text:")
    print(p_oneColumn_crop.extract_text())
    p_oneColumn.crop(one_column_bbox).to_image().show()
    print("Two Column Text:")
    print(p_twoColums_crop.extract_text())
    if not p_twoColums_crop.extract_text():
        print("IS EMPTY")
    # p_twoColums.to_image().show()
# Out:
# One Column Text:
# ρο
# εω
# δηµ
# αι
# ν ε
# ωπ
# Two Column Text:
#
# IS EMPTY

# %%
f = "pdf_files/898.pdf"


with pdfplumber.open(f) as pdf:
    p = pdf.pages[25]
    box_check_for_one_column = (295.5,65,301.8,759.5)
    box_check_for_one_column_first_page = (295.5,366,301.8,759.5)
    one_column_bbox =(0,64,p.width,799)
    one_column_bbox_first_page =(0,365,p.width,799)
    p_crop = p.crop(box_check_for_one_column)
    p_crop.to_image().show()
    # p_crop.to_image().show()
    print(p_crop.extract_text())

# %%
f = "pdf_files/1089.pdf"


with pdfplumber.open(f) as pdf:
    p = pdf.pages[7]
    box_check_for_one_column = (300,65,300.8,759.5)
    box_check_for_one_column_first_page = (295.5,366,301.8,759.5)
    one_column_bbox =(0,64,p.width,799)
    one_column_bbox_first_page =(0,365,p.width,799)
    p_crop = p.crop(box_check_for_one_column)
    # p_crop.to_image().show()
    # p_crop.to_image().show()
    print(p_crop.extract_text())
# Out:
# /

# %%
f = "pdf_files/1279.pdf"


with pdfplumber.open(f) as pdf:
    p = pdf.pages[42]
    box_check_for_one_column = (300,65,301.8,759.5)
    box_check_for_one_column_first_page = (295.5,400,301.8,759.5)
    one_column_bbox =(0,64,p.width,799)
    one_column_bbox_first_page =(0,400,p.width,799)
    p_crop = p.crop(box_check_for_one_column)
    # p_crop.to_image().show()
    # p_crop.to_image().show()
    print(p_crop.extract_text())

# %%
f = "pdf_files/1231.pdf"


with pdfplumber.open(f) as pdf:
    p = pdf.pages[2]
    box_check_for_one_column = (300,65,301.8,759.5)
    box_check_for_one_column_first_page = (295.5,400,301.8,759.5)
    one_column_bbox =(0,64,p.width,799)
    one_column_bbox_first_page =(0,400,p.width,799)
    p_crop = p.crop(box_check_for_one_column)
    # p_crop.to_image().show()
    # p_crop.to_image().show()
    print(p.extract_text())
# Out:
# 3
